# %%
from torchvision.models.segmentation import deeplabv3_resnet50, deeplabv3
import torch
import numpy as np
from torch.utils.data import Dataset, DataLoader
import os
from data_manager import create_modified_crop_labels, filter_balanced_patches, setup_training_loader
from tqdm import tqdm

# %%
weights = deeplabv3.DeepLabV3_ResNet50_Weights.COCO_WITH_VOC_LABELS_V1
model = deeplabv3_resnet50(num_classes=2)



# Get the original conv1 layer
original_conv = model.backbone.conv1

# Create a new conv1 layer with 6 input channels
new_conv = torch.nn.Conv2d(
    in_channels=18,
    out_channels=original_conv.out_channels,
    kernel_size=original_conv.kernel_size,
    stride=original_conv.stride,
    padding=original_conv.padding,
    bias=original_conv.bias is not None,
)

model.backbone.conv1 = new_conv

# %%
TARGET_CROP = -1  # The crop ID we're training to detect
UNCHANGED_CROPS = [1, 5, 23, 176]  # List of unchanged crops


train_loader = setup_training_loader(
    path_to_train_data='./training_data/train_patches.npy',
    unchanged_crops=UNCHANGED_CROPS,
    target_crops=[TARGET_CROP],
    train_batch_size=16,
    crop_band_index=18,
    device='cuda',
    ignore_crops=None,
    min_ratio=0.1,
    max_ratio=0.9
)

    # Setup validation loader
val_loader = setup_training_loader(
    path_to_train_data='./training_data/val_patches.npy',
    unchanged_crops=UNCHANGED_CROPS,
    target_crops=[TARGET_CROP],
    train_batch_size=16,
    crop_band_index=18,
    device='cuda',
    ignore_crops=None,
    min_ratio=0.1,
    max_ratio=0.9
)

test_loader = setup_training_loader(
    path_to_train_data='./training_data/test_patches.npy',
    unchanged_crops=UNCHANGED_CROPS,
    target_crops=[TARGET_CROP],
    train_batch_size=16,
    crop_band_index=18,
    device='cuda',
    ignore_crops=None,
    min_ratio=0.1,
    max_ratio=0.9
)
# Out:
# Filtered 1074 patches to 951 good patches (88.55%)
# Dataset loaded with 951 patches
# Total pixels: 47717376
# Positive pixels (+1): 18198112
# Negative pixels (-1): 29519264
# Filtered 231 patches to 207 good patches (89.61%)
# Dataset loaded with 207 patches
# Total pixels: 10386432
# Positive pixels (+1): 3942491
# Negative pixels (-1): 6443941
# Filtered 231 patches to 209 good patches (90.48%)
# Dataset loaded with 209 patches
# Total pixels: 10486784
# Positive pixels (+1): 4125291
# Negative pixels (-1): 6361493

# %%
# Since the labels are +1 and -1, we need to convert them to 0 and 1 for model compatibility
def transform_labels(labels):
    return ((labels + 1) / 2).long()  # Converts -1 to 0 and +1 to 1

# Training setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# Loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

# Function to calculate precision, recall, and F1-score for binary classification
def calculate_metrics(outputs, labels):
    _, predicted = torch.max(outputs, 1)
    true_positive = ((predicted == 1) & (labels == 1)).sum().item()
    false_positive = ((predicted == 1) & (labels == 0)).sum().item()
    false_negative = ((predicted == 0) & (labels == 1)).sum().item()
    true_negative = ((predicted == 0) & (labels == 0)).sum().item()
    
    precision = true_positive / (true_positive + false_positive) if (true_positive + false_positive) > 0 else 0
    recall = true_positive / (true_positive + false_negative) if (true_positive + false_negative) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    accuracy = (true_positive + true_negative) / (true_positive + true_negative + false_positive + false_negative)
    
    return accuracy, precision, recall, f1

# Training function
def train_epoch(model, train_loader, criterion, optimizer, device):
    model.train()
    total_loss = 0
    total_accuracy = 0
    total_precision = 0
    total_recall = 0
    total_f1 = 0
    batches = 0
    
    # Add tqdm progress bar
    pbar = tqdm(train_loader, desc='Training')
    for images, labels in pbar:
        # Move data to device
        images = images.permute(0, 3, 1, 2).to(device)  # Change to (B, C, H, W)
        labels = transform_labels(labels).to(device)
        
        # Forward pass
        outputs = model(images)['out']
        
        # Calculate loss
        loss = criterion(outputs, labels)
        
        # Backward pass and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Calculate metrics
        accuracy, precision, recall, f1 = calculate_metrics(outputs, labels)
        
        total_loss += loss.item()
        total_accuracy += accuracy
        total_precision += precision
        total_recall += recall
        total_f1 += f1
        batches += 1
        
        # Update progress bar
        pbar.set_postfix({
            'loss': f'{loss.item():.4f}',
            'acc': f'{accuracy:.4f}',
            'f1': f'{f1:.4f}'
        })
    
    return (total_loss / batches, total_accuracy / batches, 
            total_precision / batches, total_recall / batches, total_f1 / batches)

# Validation function
def validate(model, val_loader, criterion, device):
    model.eval()
    total_loss = 0
    total_accuracy = 0
    total_precision = 0
    total_recall = 0
    total_f1 = 0
    batches = 0
    
    # Add tqdm progress bar
    pbar = tqdm(val_loader, desc='Validation')
    with torch.no_grad():
        for images, labels in pbar:
            # Move data to device
            images = images.permute(0, 3, 1, 2).to(device)  # Change to (B, C, H, W)
            labels = transform_labels(labels).to(device)
            
            # Forward pass
            outputs = model(images)['out']
            
            # Calculate loss
            loss = criterion(outputs, labels)
            
            # Calculate metrics
            accuracy, precision, recall, f1 = calculate_metrics(outputs, labels)
            
            total_loss += loss.item()
            total_accuracy += accuracy
            total_precision += precision
            total_recall += recall
            total_f1 += f1
            batches += 1
            
            # Update progress bar
            pbar.set_postfix({
                'loss': f'{loss.item():.4f}',
                'acc': f'{accuracy:.4f}',
                'f1': f'{f1:.4f}'
            })
    
    return (total_loss / batches, total_accuracy / batches, 
            total_precision / batches, total_recall / batches, total_f1 / batches)

# %%
# Training loop
num_epochs = 100
best_val_f1 = 0.0

# Add tqdm for epochs
epoch_pbar = tqdm(range(num_epochs), desc='Epochs')
for epoch in epoch_pbar:
    # Training
    train_loss, train_acc, train_prec, train_rec, train_f1 = train_epoch(model, train_loader, criterion, optimizer, device)
    
    # Validation
    val_loss, val_acc, val_prec, val_rec, val_f1 = validate(model, val_loader, criterion, device)
    
    # Update learning rate
    scheduler.step()
    
    # Update epoch progress bar
    epoch_pbar.set_postfix({
        'train_loss': f'{train_loss:.4f}',
        'train_acc': f'{train_acc:.4f}',
        'train_f1': f'{train_f1:.4f}',
        'val_loss': f'{val_loss:.4f}',
        'val_acc': f'{val_acc:.4f}',
        'val_f1': f'{val_f1:.4f}'
    })
    
    # Save best model based on F1-score
    if val_f1 > best_val_f1:
        best_val_f1 = val_f1
        torch.save(model.state_dict(), 'best_model_binary.pth')
        print(f'\nNew best model saved with validation F1-score: {val_f1:.4f}')
        print(f'Validation metrics - Accuracy: {val_acc:.4f}, Precision: {val_prec:.4f}, Recall: {val_rec:.4f}')

# Load best model for testing
model.load_state_dict(torch.load('best_model_binary.pth'))

# Test the model
test_loss, test_acc, test_prec, test_rec, test_f1 = validate(model, test_loader, criterion, device)
print(f'\nTest Results:')
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_acc:.4f}')
print(f'Test Precision: {test_prec:.4f}')
print(f'Test Recall: {test_rec:.4f}')
print(f'Test F1-score: {test_f1:.4f}')
# Out:
# Epochs:   0%|                 | 0/100 [00:00<?, ?it/s]
# Training:   0%|                | 0/32 [00:00<?, ?it/s]
# Training:   0%| | 0/32 [00:02<?, ?it/s, loss=0.6835, a
# Training:   3%| | 1/32 [00:02<01:19,  2.56s/it, loss=0
# Training:   3%| | 1/32 [00:04<01:19,  2.56s/it, loss=0
# Training:   6%| | 2/32 [00:04<01:11,  2.38s/it, loss=0
# Training:   6%| | 2/32 [00:07<01:11,  2.38s/it, loss=1
# Training:   9%| | 3/32 [00:07<01:07,  2.32s/it, loss=1
# Training:   9%| | 3/32 [00:09<01:07,  2.32s/it, loss=1
# Training:  12%|▏| 4/32 [00:09<01:04,  2.29s/it, loss=1
# Training:  12%|▏| 4/32 [00:11<01:04,  2.29s/it, loss=0
# Training:  16%|▏| 5/32 [00:11<01:01,  2.27s/it, loss=0
# Training:  16%|▏| 5/32 [00:13<01:01,  2.27s/it, loss=0
# Training:  19%|▏| 6/32 [00:13<00:58,  2.26s/it, loss=0
# Training:  19%|▏| 6/32 [00:16<00:58,  2.26s/it, loss=0
# Training:  22%|▏| 7/32 [00:16<00:56,  2.26s/it, loss=0
# Training:  22%|▏| 7/32 [00:18<00:56,  2.26s/it, loss=0
# Training:  25%|▎| 8/32 [00:18<00:54,  2.25s/it, loss=0
# Training:  25%|▎| 8/32 [00:20<00:54,  2.25s/it, loss=0
# Training:  28%|▎| 9/32 [00:20<00:51,  2.25s/it, loss=0
# Training:  28%|▎| 9/32 [00:22<00:51,  2.25s/it, loss=0
# Training:  31%|▎| 10/32 [00:22<00:49,  2.25s/it, loss=
# Training:  31%|▎| 10/32 [00:25<00:49,  2.25s/it, loss=
# Training:  34%|▎| 11/32 [00:25<00:47,  2.25s/it, loss=
# Training:  34%|▎| 11/32 [00:27<00:47,  2.25s/it, loss=
# Training:  38%|▍| 12/32 [00:27<00:44,  2.24s/it, loss=
# Training:  38%|▍| 12/32 [00:29<00:44,  2.24s/it, loss=
# Training:  41%|▍| 13/32 [00:29<00:42,  2.24s/it, loss=
# Training:  41%|▍| 13/32 [00:31<00:42,  2.24s/it, loss=
# Training:  44%|▍| 14/32 [00:31<00:40,  2.24s/it, loss=
# Training:  44%|▍| 14/32 [00:33<00:40,  2.24s/it, loss=
# Training:  47%|▍| 15/32 [00:33<00:38,  2.24s/it, loss=
# Training:  47%|▍| 15/32 [00:36<00:38,  2.24s/it, loss=
# Training:  50%|▌| 16/32 [00:36<00:35,  2.24s/it, loss=
# Training:  50%|▌| 16/32 [00:38<00:35,  2.24s/it, loss=
# Training:  53%|▌| 17/32 [00:38<00:33,  2.25s/it, loss=
# Training:  53%|▌| 17/32 [00:40<00:33,  2.25s/it, loss=
# Training:  56%|▌| 18/32 [00:40<00:31,  2.25s/it, loss=
# Training:  56%|▌| 18/32 [00:42<00:31,  2.25s/it, loss=
# Training:  59%|▌| 19/32 [00:42<00:29,  2.25s/it, loss=
# Training:  59%|▌| 19/32 [00:45<00:29,  2.25s/it, loss=
# Training:  62%|▋| 20/32 [00:45<00:26,  2.25s/it, loss=
# Training:  62%|▋| 20/32 [00:47<00:26,  2.25s/it, loss=
# Training:  66%|▋| 21/32 [00:47<00:24,  2.25s/it, loss=
# Training:  66%|▋| 21/32 [00:49<00:24,  2.25s/it, loss=
# Training:  69%|▋| 22/32 [00:49<00:22,  2.25s/it, loss=
# Training:  69%|▋| 22/32 [00:51<00:22,  2.25s/it, loss=
# Training:  72%|▋| 23/32 [00:51<00:20,  2.25s/it, loss=
# Training:  72%|▋| 23/32 [00:54<00:20,  2.25s/it, loss=
# Training:  75%|▊| 24/32 [00:54<00:17,  2.25s/it, loss=
# Training:  75%|▊| 24/32 [00:56<00:17,  2.25s/it, loss=
# Training:  78%|▊| 25/32 [00:56<00:15,  2.25s/it, loss=
# Training:  78%|▊| 25/32 [00:58<00:15,  2.25s/it, loss=
# Training:  81%|▊| 26/32 [00:58<00:13,  2.25s/it, loss=
# Training:  81%|▊| 26/32 [01:00<00:13,  2.25s/it, loss=
# Training:  84%|▊| 27/32 [01:00<00:11,  2.25s/it, loss=
# Training:  84%|▊| 27/32 [01:03<00:11,  2.25s/it, loss=
# Training:  88%|▉| 28/32 [01:03<00:08,  2.25s/it, loss=
# Training:  88%|▉| 28/32 [01:05<00:08,  2.25s/it, loss=
# Training:  91%|▉| 29/32 [01:05<00:06,  2.25s/it, loss=
# Training:  91%|▉| 29/32 [01:07<00:06,  2.25s/it, loss=
# Training:  94%|▉| 30/32 [01:07<00:04,  2.25s/it, loss=
# Training:  94%|▉| 30/32 [01:09<00:04,  2.25s/it, loss=
# Training:  97%|▉| 31/32 [01:09<00:02,  2.25s/it, loss=
# Training:  97%|▉| 31/32 [01:12<00:02,  2.25s/it, loss=
# Training: 100%|█| 32/32 [01:12<00:00,  2.25s/it, loss=
#
# Validation:   0%|               | 0/7 [00:00<?, ?it/s]
# Validation:   0%| | 0/7 [00:00<?, ?it/s, loss=0.6950,
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.91it/s, loss=
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.91it/s, loss=
# Validation:  29%|▎| 2/7 [00:00<00:01,  2.94it/s, loss=
# Validation:  29%|▎| 2/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  71%|▋| 5/7 [00:01<00:00,  2.94it/s, loss=
# Validation:  71%|▋| 5/7 [00:02<00:00,  2.94it/s, loss=
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.94it/s, loss=
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.94it/s, loss=
# Validation: 100%|█| 7/7 [00:02<00:00,  2.93it/s, loss=
# Epochs:   1%| | 1/100 [01:14<2:03:11, 74.66s/it, train
# New best model saved with validation F1-score: 0.0068
# Validation metrics - Accuracy: 0.6783, Precision: 0.4296, Recall: 0.0034
# Training:   0%|                | 0/32 [00:00<?, ?it/s]
# Training:   0%| | 0/32 [00:02<?, ?it/s, loss=0.5006, a
# Training:   3%| | 1/32 [00:02<01:09,  2.24s/it, loss=0
# Training:   3%| | 1/32 [00:04<01:09,  2.24s/it, loss=0
# Training:   6%| | 2/32 [00:04<01:07,  2.25s/it, loss=0
# Training:   6%| | 2/32 [00:06<01:07,  2.25s/it, loss=0
# Training:   9%| | 3/32 [00:06<01:05,  2.24s/it, loss=0
# Training:   9%| | 3/32 [00:08<01:05,  2.24s/it, loss=0
# Training:  12%|▏| 4/32 [00:08<01:02,  2.25s/it, loss=0
# Training:  12%|▏| 4/32 [00:11<01:02,  2.25s/it, loss=0
# Training:  16%|▏| 5/32 [00:11<01:00,  2.25s/it, loss=0
# Training:  16%|▏| 5/32 [00:13<01:00,  2.25s/it, loss=0
# Training:  19%|▏| 6/32 [00:13<00:58,  2.25s/it, loss=0
# Training:  19%|▏| 6/32 [00:15<00:58,  2.25s/it, loss=0
# Training:  22%|▏| 7/32 [00:15<00:56,  2.25s/it, loss=0
# Training:  22%|▏| 7/32 [00:17<00:56,  2.25s/it, loss=0
# Training:  25%|▎| 8/32 [00:17<00:53,  2.25s/it, loss=0
# Training:  25%|▎| 8/32 [00:20<00:53,  2.25s/it, loss=0
# Training:  28%|▎| 9/32 [00:20<00:51,  2.25s/it, loss=0
# Training:  28%|▎| 9/32 [00:22<00:51,  2.25s/it, loss=0
# Training:  31%|▎| 10/32 [00:22<00:49,  2.25s/it, loss=
# Training:  31%|▎| 10/32 [00:24<00:49,  2.25s/it, loss=
# Training:  34%|▎| 11/32 [00:24<00:47,  2.25s/it, loss=
# Training:  34%|▎| 11/32 [00:26<00:47,  2.25s/it, loss=
# Training:  38%|▍| 12/32 [00:26<00:44,  2.25s/it, loss=
# Training:  38%|▍| 12/32 [00:29<00:44,  2.25s/it, loss=
# Training:  41%|▍| 13/32 [00:29<00:42,  2.25s/it, loss=
# Training:  41%|▍| 13/32 [00:31<00:42,  2.25s/it, loss=
# Training:  44%|▍| 14/32 [00:31<00:40,  2.25s/it, loss=
# Training:  44%|▍| 14/32 [00:33<00:40,  2.25s/it, loss=
# Training:  47%|▍| 15/32 [00:33<00:38,  2.25s/it, loss=
# Training:  47%|▍| 15/32 [00:35<00:38,  2.25s/it, loss=
# Training:  50%|▌| 16/32 [00:35<00:35,  2.25s/it, loss=
# Training:  50%|▌| 16/32 [00:38<00:35,  2.25s/it, loss=
# Training:  53%|▌| 17/32 [00:38<00:33,  2.25s/it, loss=
# Training:  53%|▌| 17/32 [00:40<00:33,  2.25s/it, loss=
# Training:  56%|▌| 18/32 [00:40<00:31,  2.25s/it, loss=
# Training:  56%|▌| 18/32 [00:42<00:31,  2.25s/it, loss=
# Training:  59%|▌| 19/32 [00:42<00:29,  2.25s/it, loss=
# Training:  59%|▌| 19/32 [00:44<00:29,  2.25s/it, loss=
# Training:  62%|▋| 20/32 [00:44<00:26,  2.25s/it, loss=
# Training:  62%|▋| 20/32 [00:47<00:26,  2.25s/it, loss=
# Training:  66%|▋| 21/32 [00:47<00:24,  2.25s/it, loss=
# Training:  66%|▋| 21/32 [00:49<00:24,  2.25s/it, loss=
# Training:  69%|▋| 22/32 [00:49<00:22,  2.25s/it, loss=
# Training:  69%|▋| 22/32 [00:51<00:22,  2.25s/it, loss=
# Training:  72%|▋| 23/32 [00:51<00:20,  2.25s/it, loss=
# Training:  72%|▋| 23/32 [00:53<00:20,  2.25s/it, loss=
# Training:  75%|▊| 24/32 [00:53<00:18,  2.25s/it, loss=
# Training:  75%|▊| 24/32 [00:56<00:18,  2.25s/it, loss=
# Training:  78%|▊| 25/32 [00:56<00:15,  2.25s/it, loss=
# Training:  78%|▊| 25/32 [00:58<00:15,  2.25s/it, loss=
# Training:  81%|▊| 26/32 [00:58<00:13,  2.25s/it, loss=
# Training:  81%|▊| 26/32 [01:00<00:13,  2.25s/it, loss=
# Training:  84%|▊| 27/32 [01:00<00:11,  2.25s/it, loss=
# Training:  84%|▊| 27/32 [01:02<00:11,  2.25s/it, loss=
# Training:  88%|▉| 28/32 [01:02<00:09,  2.25s/it, loss=
# Training:  88%|▉| 28/32 [01:05<00:09,  2.25s/it, loss=
# Training:  91%|▉| 29/32 [01:05<00:06,  2.25s/it, loss=
# Training:  91%|▉| 29/32 [01:07<00:06,  2.25s/it, loss=
# Training:  94%|▉| 30/32 [01:07<00:04,  2.25s/it, loss=
# Training:  94%|▉| 30/32 [01:09<00:04,  2.25s/it, loss=
# Training:  97%|▉| 31/32 [01:09<00:02,  2.25s/it, loss=
# Training:  97%|▉| 31/32 [01:11<00:02,  2.25s/it, loss=
# Training: 100%|█| 32/32 [01:11<00:00,  2.25s/it, loss=
#
# Validation:   0%|               | 0/7 [00:00<?, ?it/s]
# Validation:   0%| | 0/7 [00:00<?, ?it/s, loss=0.3416,
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.94it/s, loss=
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.94it/s, loss=
# Validation:  29%|▎| 2/7 [00:00<00:01,  2.94it/s, loss=
# Validation:  29%|▎| 2/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.93it/s, loss=
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.93it/s, loss=
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.93it/s, loss=
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.93it/s, loss=
# Validation:  71%|▋| 5/7 [00:01<00:00,  2.93it/s, loss=
# Validation:  71%|▋| 5/7 [00:02<00:00,  2.93it/s, loss=
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.92it/s, loss=
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.92it/s, loss=
# Validation: 100%|█| 7/7 [00:02<00:00,  2.91it/s, loss=
# Epochs:   2%| | 2/100 [02:29<2:01:52, 74.62s/it, train
# New best model saved with validation F1-score: 0.7720
# Validation metrics - Accuracy: 0.8465, Precision: 0.7329, Recall: 0.8166
# Training:   0%|                | 0/32 [00:00<?, ?it/s]
# Training:   0%| | 0/32 [00:02<?, ?it/s, loss=0.3739, a
# Training:   3%| | 1/32 [00:02<01:09,  2.26s/it, loss=0
# Training:   3%| | 1/32 [00:04<01:09,  2.26s/it, loss=0
# Training:   6%| | 2/32 [00:04<01:07,  2.25s/it, loss=0
# Training:   6%| | 2/32 [00:06<01:07,  2.25s/it, loss=0
# Training:   9%| | 3/32 [00:06<01:05,  2.25s/it, loss=0
# Training:   9%| | 3/32 [00:09<01:05,  2.25s/it, loss=0
# Training:  12%|▏| 4/32 [00:09<01:03,  2.25s/it, loss=0
# Training:  12%|▏| 4/32 [00:11<01:03,  2.25s/it, loss=0
# Training:  16%|▏| 5/32 [00:11<01:00,  2.25s/it, loss=0
# Training:  16%|▏| 5/32 [00:13<01:00,  2.25s/it, loss=0
# Training:  19%|▏| 6/32 [00:13<00:58,  2.25s/it, loss=0
# Training:  19%|▏| 6/32 [00:15<00:58,  2.25s/it, loss=0
# Training:  22%|▏| 7/32 [00:15<00:56,  2.25s/it, loss=0
# Training:  22%|▏| 7/32 [00:18<00:56,  2.25s/it, loss=0
# Training:  25%|▎| 8/32 [00:18<00:54,  2.25s/it, loss=0
# Training:  25%|▎| 8/32 [00:20<00:54,  2.25s/it, loss=0
# Training:  28%|▎| 9/32 [00:20<00:51,  2.25s/it, loss=0
# Training:  28%|▎| 9/32 [00:22<00:51,  2.25s/it, loss=0
# Training:  31%|▎| 10/32 [00:22<00:49,  2.25s/it, loss=
# Training:  31%|▎| 10/32 [00:24<00:49,  2.25s/it, loss=
# Training:  34%|▎| 11/32 [00:24<00:47,  2.25s/it, loss=
# Training:  34%|▎| 11/32 [00:27<00:47,  2.25s/it, loss=
# Training:  38%|▍| 12/32 [00:27<00:45,  2.25s/it, loss=
# Training:  38%|▍| 12/32 [00:29<00:45,  2.25s/it, loss=
# Training:  41%|▍| 13/32 [00:29<00:42,  2.25s/it, loss=
# Training:  41%|▍| 13/32 [00:31<00:42,  2.25s/it, loss=
# Training:  44%|▍| 14/32 [00:31<00:40,  2.25s/it, loss=
# Training:  44%|▍| 14/32 [00:33<00:40,  2.25s/it, loss=
# Training:  47%|▍| 15/32 [00:33<00:38,  2.25s/it, loss=
# Training:  47%|▍| 15/32 [00:36<00:38,  2.25s/it, loss=
# Training:  50%|▌| 16/32 [00:36<00:36,  2.25s/it, loss=
# Training:  50%|▌| 16/32 [00:38<00:36,  2.25s/it, loss=
# Training:  53%|▌| 17/32 [00:38<00:33,  2.25s/it, loss=
# Training:  53%|▌| 17/32 [00:40<00:33,  2.25s/it, loss=
# Training:  56%|▌| 18/32 [00:40<00:31,  2.25s/it, loss=
# Training:  56%|▌| 18/32 [00:42<00:31,  2.25s/it, loss=
# Training:  59%|▌| 19/32 [00:42<00:29,  2.25s/it, loss=
# Training:  59%|▌| 19/32 [00:45<00:29,  2.25s/it, loss=
# Training:  62%|▋| 20/32 [00:45<00:27,  2.25s/it, loss=
# Training:  62%|▋| 20/32 [00:47<00:27,  2.25s/it, loss=
# Training:  66%|▋| 21/32 [00:47<00:24,  2.25s/it, loss=
# Training:  66%|▋| 21/32 [00:49<00:24,  2.25s/it, loss=
# Training:  69%|▋| 22/32 [00:49<00:22,  2.25s/it, loss=
# Training:  69%|▋| 22/32 [00:51<00:22,  2.25s/it, loss=
# Training:  72%|▋| 23/32 [00:51<00:20,  2.25s/it, loss=
# Training:  72%|▋| 23/32 [00:54<00:20,  2.25s/it, loss=
# Training:  75%|▊| 24/32 [00:54<00:18,  2.25s/it, loss=
# Training:  75%|▊| 24/32 [00:56<00:18,  2.25s/it, loss=
# Training:  78%|▊| 25/32 [00:56<00:15,  2.25s/it, loss=
# Training:  78%|▊| 25/32 [00:58<00:15,  2.25s/it, loss=
# Training:  81%|▊| 26/32 [00:58<00:13,  2.25s/it, loss=
# Training:  81%|▊| 26/32 [01:00<00:13,  2.25s/it, loss=
# Training:  84%|▊| 27/32 [01:00<00:11,  2.25s/it, loss=
# Training:  84%|▊| 27/32 [01:03<00:11,  2.25s/it, loss=
# Training:  88%|▉| 28/32 [01:03<00:09,  2.25s/it, loss=
# Training:  88%|▉| 28/32 [01:05<00:09,  2.25s/it, loss=
# Training:  91%|▉| 29/32 [01:05<00:06,  2.25s/it, loss=
# Training:  91%|▉| 29/32 [01:07<00:06,  2.25s/it, loss=
# Training:  94%|▉| 30/32 [01:07<00:04,  2.25s/it, loss=
# Training:  94%|▉| 30/32 [01:09<00:04,  2.25s/it, loss=
# Training:  97%|▉| 31/32 [01:09<00:02,  2.25s/it, loss=
# Training:  97%|▉| 31/32 [01:12<00:02,  2.25s/it, loss=
# Training: 100%|█| 32/32 [01:12<00:00,  2.25s/it, loss=
#
# Validation:   0%|               | 0/7 [00:00<?, ?it/s]
# Validation:   0%| | 0/7 [00:00<?, ?it/s, loss=0.2934,
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.96it/s, loss=
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.96it/s, loss=
# Validation:  29%|▎| 2/7 [00:00<00:01,  2.93it/s, loss=
# Validation:  29%|▎| 2/7 [00:01<00:01,  2.93it/s, loss=
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.92it/s, loss=
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.92it/s, loss=
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.92it/s, loss=
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.92it/s, loss=
# Validation:  71%|▋| 5/7 [00:01<00:00,  2.92it/s, loss=
# Validation:  71%|▋| 5/7 [00:02<00:00,  2.92it/s, loss=
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.93it/s, loss=
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.93it/s, loss=
# Validation: 100%|█| 7/7 [00:02<00:00,  2.91it/s, loss=
# Epochs:   3%| | 3/100 [03:43<2:00:41, 74.66s/it, train
# New best model saved with validation F1-score: 0.8141
# Validation metrics - Accuracy: 0.8681, Precision: 0.7382, Recall: 0.9084
# Training:   0%|                | 0/32 [00:00<?, ?it/s]
# Training:   0%| | 0/32 [00:02<?, ?it/s, loss=0.2813, a
# Training:   3%| | 1/32 [00:02<01:10,  2.26s/it, loss=0
# Training:   3%| | 1/32 [00:04<01:10,  2.26s/it, loss=0
# Training:   6%| | 2/32 [00:04<01:07,  2.26s/it, loss=0
# Training:   6%| | 2/32 [00:06<01:07,  2.26s/it, loss=0
# Training:   9%| | 3/32 [00:06<01:05,  2.25s/it, loss=0
# Training:   9%| | 3/32 [00:09<01:05,  2.25s/it, loss=0
# Training:  12%|▏| 4/32 [00:09<01:03,  2.25s/it, loss=0
# Training:  12%|▏| 4/32 [00:11<01:03,  2.25s/it, loss=0
# Training:  16%|▏| 5/32 [00:11<01:00,  2.25s/it, loss=0
# Training:  16%|▏| 5/32 [00:13<01:00,  2.25s/it, loss=0
# Training:  19%|▏| 6/32 [00:13<00:58,  2.25s/it, loss=0
# Training:  19%|▏| 6/32 [00:15<00:58,  2.25s/it, loss=0
# Training:  22%|▏| 7/32 [00:15<00:56,  2.25s/it, loss=0
# Training:  22%|▏| 7/32 [00:18<00:56,  2.25s/it, loss=0
# Training:  25%|▎| 8/32 [00:18<00:54,  2.25s/it, loss=0
# Training:  25%|▎| 8/32 [00:20<00:54,  2.25s/it, loss=0
# Training:  28%|▎| 9/32 [00:20<00:51,  2.25s/it, loss=0
# Training:  28%|▎| 9/32 [00:22<00:51,  2.25s/it, loss=0
# Training:  31%|▎| 10/32 [00:22<00:49,  2.25s/it, loss=
# Training:  31%|▎| 10/32 [00:24<00:49,  2.25s/it, loss=
# Training:  34%|▎| 11/32 [00:24<00:47,  2.25s/it, loss=
# Training:  34%|▎| 11/32 [00:27<00:47,  2.25s/it, loss=
# Training:  38%|▍| 12/32 [00:27<00:45,  2.25s/it, loss=
# Training:  38%|▍| 12/32 [00:29<00:45,  2.25s/it, loss=
# Training:  41%|▍| 13/32 [00:29<00:42,  2.25s/it, loss=
# Training:  41%|▍| 13/32 [00:31<00:42,  2.25s/it, loss=
# Training:  44%|▍| 14/32 [00:31<00:40,  2.25s/it, loss=
# Training:  44%|▍| 14/32 [00:33<00:40,  2.25s/it, loss=
# Training:  47%|▍| 15/32 [00:33<00:38,  2.25s/it, loss=
# Training:  47%|▍| 15/32 [00:36<00:38,  2.25s/it, loss=
# Training:  50%|▌| 16/32 [00:36<00:36,  2.25s/it, loss=
# Training:  50%|▌| 16/32 [00:38<00:36,  2.25s/it, loss=
# Training:  53%|▌| 17/32 [00:38<00:33,  2.25s/it, loss=
# Training:  53%|▌| 17/32 [00:40<00:33,  2.25s/it, loss=
# Training:  56%|▌| 18/32 [00:40<00:31,  2.25s/it, loss=
# Training:  56%|▌| 18/32 [00:42<00:31,  2.25s/it, loss=
# Training:  59%|▌| 19/32 [00:42<00:29,  2.25s/it, loss=
# Training:  59%|▌| 19/32 [00:45<00:29,  2.25s/it, loss=
# Training:  62%|▋| 20/32 [00:45<00:27,  2.25s/it, loss=
# Training:  62%|▋| 20/32 [00:47<00:27,  2.25s/it, loss=
# Training:  66%|▋| 21/32 [00:47<00:24,  2.25s/it, loss=
# Training:  66%|▋| 21/32 [00:49<00:24,  2.25s/it, loss=
# Training:  69%|▋| 22/32 [00:49<00:22,  2.25s/it, loss=
# Training:  69%|▋| 22/32 [00:51<00:22,  2.25s/it, loss=
# Training:  72%|▋| 23/32 [00:51<00:20,  2.25s/it, loss=
# Training:  72%|▋| 23/32 [00:54<00:20,  2.25s/it, loss=
# Training:  75%|▊| 24/32 [00:54<00:18,  2.25s/it, loss=
# Training:  75%|▊| 24/32 [00:56<00:18,  2.25s/it, loss=
# Training:  78%|▊| 25/32 [00:56<00:15,  2.25s/it, loss=
# Training:  78%|▊| 25/32 [00:58<00:15,  2.25s/it, loss=
# Training:  81%|▊| 26/32 [00:58<00:13,  2.25s/it, loss=
# Training:  81%|▊| 26/32 [01:00<00:13,  2.25s/it, loss=
# Training:  84%|▊| 27/32 [01:00<00:11,  2.25s/it, loss=
# Training:  84%|▊| 27/32 [01:03<00:11,  2.25s/it, loss=
# Training:  88%|▉| 28/32 [01:03<00:09,  2.25s/it, loss=
# Training:  88%|▉| 28/32 [01:05<00:09,  2.25s/it, loss=
# Training:  91%|▉| 29/32 [01:05<00:06,  2.25s/it, loss=
# Training:  91%|▉| 29/32 [01:07<00:06,  2.25s/it, loss=
# Training:  94%|▉| 30/32 [01:07<00:04,  2.25s/it, loss=
# Training:  94%|▉| 30/32 [01:09<00:04,  2.25s/it, loss=
# Training:  97%|▉| 31/32 [01:09<00:02,  2.25s/it, loss=
# Training:  97%|▉| 31/32 [01:12<00:02,  2.25s/it, loss=
# Training: 100%|█| 32/32 [01:12<00:00,  2.25s/it, loss=
#
# Validation:   0%|               | 0/7 [00:00<?, ?it/s]
# Validation:   0%| | 0/7 [00:00<?, ?it/s, loss=0.2301,
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.94it/s, loss=
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.94it/s, loss=
# Validation:  29%|▎| 2/7 [00:00<00:01,  2.94it/s, loss=
# Validation:  29%|▎| 2/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.93it/s, loss=
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.93it/s, loss=
# Validation:  71%|▋| 5/7 [00:01<00:00,  2.93it/s, loss=
# Validation:  71%|▋| 5/7 [00:02<00:00,  2.93it/s, loss=
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.93it/s, loss=
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.93it/s, loss=
# Validation: 100%|█| 7/7 [00:02<00:00,  2.92it/s, loss=
# Epochs:   4%| | 4/100 [04:58<1:59:28, 74.67s/it, train
# New best model saved with validation F1-score: 0.8498
# Validation metrics - Accuracy: 0.9039, Precision: 0.8416, Recall: 0.8584
# Training:   0%|                | 0/32 [00:00<?, ?it/s]
# Training:   0%| | 0/32 [00:02<?, ?it/s, loss=0.2484, a
# Training:   3%| | 1/32 [00:02<01:09,  2.25s/it, loss=0
# Training:   3%| | 1/32 [00:04<01:09,  2.25s/it, loss=0
# Training:   6%| | 2/32 [00:04<01:07,  2.25s/it, loss=0
# Training:   6%| | 2/32 [00:06<01:07,  2.25s/it, loss=0
# Training:   9%| | 3/32 [00:06<01:05,  2.25s/it, loss=0
# Training:   9%| | 3/32 [00:09<01:05,  2.25s/it, loss=0
# Training:  12%|▏| 4/32 [00:09<01:03,  2.25s/it, loss=0
# Training:  12%|▏| 4/32 [00:11<01:03,  2.25s/it, loss=0
# Training:  16%|▏| 5/32 [00:11<01:00,  2.25s/it, loss=0
# Training:  16%|▏| 5/32 [00:13<01:00,  2.25s/it, loss=0
# Training:  19%|▏| 6/32 [00:13<00:58,  2.25s/it, loss=0
# Training:  19%|▏| 6/32 [00:15<00:58,  2.25s/it, loss=0
# Training:  22%|▏| 7/32 [00:15<00:56,  2.25s/it, loss=0
# Training:  22%|▏| 7/32 [00:18<00:56,  2.25s/it, loss=0
# Training:  25%|▎| 8/32 [00:18<00:54,  2.25s/it, loss=0
# Training:  25%|▎| 8/32 [00:20<00:54,  2.25s/it, loss=0
# Training:  28%|▎| 9/32 [00:20<00:51,  2.25s/it, loss=0
# Training:  28%|▎| 9/32 [00:22<00:51,  2.25s/it, loss=0
# Training:  31%|▎| 10/32 [00:22<00:49,  2.25s/it, loss=
# Training:  31%|▎| 10/32 [00:24<00:49,  2.25s/it, loss=
# Training:  34%|▎| 11/32 [00:24<00:47,  2.25s/it, loss=
# Training:  34%|▎| 11/32 [00:27<00:47,  2.25s/it, loss=
# Training:  38%|▍| 12/32 [00:27<00:45,  2.25s/it, loss=
# Training:  38%|▍| 12/32 [00:29<00:45,  2.25s/it, loss=
# Training:  41%|▍| 13/32 [00:29<00:42,  2.25s/it, loss=
# Training:  41%|▍| 13/32 [00:31<00:42,  2.25s/it, loss=
# Training:  44%|▍| 14/32 [00:31<00:40,  2.25s/it, loss=
# Training:  44%|▍| 14/32 [00:33<00:40,  2.25s/it, loss=
# Training:  47%|▍| 15/32 [00:33<00:38,  2.25s/it, loss=
# Training:  47%|▍| 15/32 [00:36<00:38,  2.25s/it, loss=
# Training:  50%|▌| 16/32 [00:36<00:36,  2.25s/it, loss=
# Training:  50%|▌| 16/32 [00:38<00:36,  2.25s/it, loss=
# Training:  53%|▌| 17/32 [00:38<00:33,  2.25s/it, loss=
# Training:  53%|▌| 17/32 [00:40<00:33,  2.25s/it, loss=
# Training:  56%|▌| 18/32 [00:40<00:31,  2.25s/it, loss=
# Training:  56%|▌| 18/32 [00:42<00:31,  2.25s/it, loss=
# Training:  59%|▌| 19/32 [00:42<00:29,  2.25s/it, loss=
# Training:  59%|▌| 19/32 [00:45<00:29,  2.25s/it, loss=
# Training:  62%|▋| 20/32 [00:45<00:27,  2.25s/it, loss=
# Training:  62%|▋| 20/32 [00:47<00:27,  2.25s/it, loss=
# Training:  66%|▋| 21/32 [00:47<00:24,  2.25s/it, loss=
# Training:  66%|▋| 21/32 [00:49<00:24,  2.25s/it, loss=
# Training:  69%|▋| 22/32 [00:49<00:22,  2.25s/it, loss=
# Training:  69%|▋| 22/32 [00:51<00:22,  2.25s/it, loss=
# Training:  72%|▋| 23/32 [00:51<00:20,  2.25s/it, loss=
# Training:  72%|▋| 23/32 [00:54<00:20,  2.25s/it, loss=
# Training:  75%|▊| 24/32 [00:54<00:18,  2.25s/it, loss=
# Training:  75%|▊| 24/32 [00:56<00:18,  2.25s/it, loss=
# Training:  78%|▊| 25/32 [00:56<00:15,  2.25s/it, loss=
# Training:  78%|▊| 25/32 [00:58<00:15,  2.25s/it, loss=
# Training:  81%|▊| 26/32 [00:58<00:13,  2.25s/it, loss=
# Training:  81%|▊| 26/32 [01:00<00:13,  2.25s/it, loss=
# Training:  84%|▊| 27/32 [01:00<00:11,  2.25s/it, loss=
# Training:  84%|▊| 27/32 [01:03<00:11,  2.25s/it, loss=
# Training:  88%|▉| 28/32 [01:03<00:09,  2.25s/it, loss=
# Training:  88%|▉| 28/32 [01:05<00:09,  2.25s/it, loss=
# Training:  91%|▉| 29/32 [01:05<00:06,  2.25s/it, loss=
# Training:  91%|▉| 29/32 [01:07<00:06,  2.25s/it, loss=
# Training:  94%|▉| 30/32 [01:07<00:04,  2.25s/it, loss=
# Training:  94%|▉| 30/32 [01:09<00:04,  2.25s/it, loss=
# Training:  97%|▉| 31/32 [01:09<00:02,  2.25s/it, loss=
# Training:  97%|▉| 31/32 [01:11<00:02,  2.25s/it, loss=
# Training: 100%|█| 32/32 [01:11<00:00,  2.25s/it, loss=
#
# Validation:   0%|               | 0/7 [00:00<?, ?it/s]
# Validation:   0%| | 0/7 [00:00<?, ?it/s, loss=0.2601,
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.94it/s, loss=
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.94it/s, loss=
# Validation:  29%|▎| 2/7 [00:00<00:01,  2.94it/s, loss=
# Validation:  29%|▎| 2/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  71%|▋| 5/7 [00:01<00:00,  2.94it/s, loss=
# Validation:  71%|▋| 5/7 [00:02<00:00,  2.94it/s, loss=
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.94it/s, loss=
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.94it/s, loss=
# Validation: 100%|█| 7/7 [00:02<00:00,  2.92it/s, loss=
# Epochs:   5%| | 5/100 [06:13<1:58:12, 74.66s/it, train
# New best model saved with validation F1-score: 0.8519
# Validation metrics - Accuracy: 0.9022, Precision: 0.8209, Recall: 0.8856
# Training:   0%|                | 0/32 [00:00<?, ?it/s]
# Training:   0%| | 0/32 [00:02<?, ?it/s, loss=0.2195, a
# Training:   3%| | 1/32 [00:02<01:09,  2.25s/it, loss=0
# Training:   3%| | 1/32 [00:04<01:09,  2.25s/it, loss=0
# Training:   6%| | 2/32 [00:04<01:07,  2.25s/it, loss=0
# Training:   6%| | 2/32 [00:06<01:07,  2.25s/it, loss=0
# Training:   9%| | 3/32 [00:06<01:05,  2.25s/it, loss=0
# Training:   9%| | 3/32 [00:09<01:05,  2.25s/it, loss=0
# Training:  12%|▏| 4/32 [00:09<01:03,  2.25s/it, loss=0
# Training:  12%|▏| 4/32 [00:11<01:03,  2.25s/it, loss=0
# Training:  16%|▏| 5/32 [00:11<01:00,  2.25s/it, loss=0
# Training:  16%|▏| 5/32 [00:13<01:00,  2.25s/it, loss=0
# Training:  19%|▏| 6/32 [00:13<00:58,  2.25s/it, loss=0
# Training:  19%|▏| 6/32 [00:15<00:58,  2.25s/it, loss=0
# Training:  22%|▏| 7/32 [00:15<00:56,  2.25s/it, loss=0
# Training:  22%|▏| 7/32 [00:18<00:56,  2.25s/it, loss=0
# Training:  25%|▎| 8/32 [00:18<00:54,  2.26s/it, loss=0
# Training:  25%|▎| 8/32 [00:20<00:54,  2.26s/it, loss=0
# Training:  28%|▎| 9/32 [00:20<00:51,  2.25s/it, loss=0
# Training:  28%|▎| 9/32 [00:22<00:51,  2.25s/it, loss=0
# Training:  31%|▎| 10/32 [00:22<00:49,  2.25s/it, loss=
# Training:  31%|▎| 10/32 [00:24<00:49,  2.25s/it, loss=
# Training:  34%|▎| 11/32 [00:24<00:47,  2.25s/it, loss=
# Training:  34%|▎| 11/32 [00:27<00:47,  2.25s/it, loss=
# Training:  38%|▍| 12/32 [00:27<00:45,  2.25s/it, loss=
# Training:  38%|▍| 12/32 [00:29<00:45,  2.25s/it, loss=
# Training:  41%|▍| 13/32 [00:29<00:42,  2.25s/it, loss=
# Training:  41%|▍| 13/32 [00:31<00:42,  2.25s/it, loss=
# Training:  44%|▍| 14/32 [00:31<00:40,  2.25s/it, loss=
# Training:  44%|▍| 14/32 [00:33<00:40,  2.25s/it, loss=
# Training:  47%|▍| 15/32 [00:33<00:38,  2.25s/it, loss=
# Training:  47%|▍| 15/32 [00:36<00:38,  2.25s/it, loss=
# Training:  50%|▌| 16/32 [00:36<00:36,  2.25s/it, loss=
# Training:  50%|▌| 16/32 [00:38<00:36,  2.25s/it, loss=
# Training:  53%|▌| 17/32 [00:38<00:33,  2.25s/it, loss=
# Training:  53%|▌| 17/32 [00:40<00:33,  2.25s/it, loss=
# Training:  56%|▌| 18/32 [00:40<00:31,  2.25s/it, loss=
# Training:  56%|▌| 18/32 [00:42<00:31,  2.25s/it, loss=
# Training:  59%|▌| 19/32 [00:42<00:29,  2.25s/it, loss=
# Training:  59%|▌| 19/32 [00:45<00:29,  2.25s/it, loss=
# Training:  62%|▋| 20/32 [00:45<00:27,  2.25s/it, loss=
# Training:  62%|▋| 20/32 [00:47<00:27,  2.25s/it, loss=
# Training:  66%|▋| 21/32 [00:47<00:24,  2.25s/it, loss=
# Training:  66%|▋| 21/32 [00:49<00:24,  2.25s/it, loss=
# Training:  69%|▋| 22/32 [00:49<00:22,  2.25s/it, loss=
# Training:  69%|▋| 22/32 [00:51<00:22,  2.25s/it, loss=
# Training:  72%|▋| 23/32 [00:51<00:20,  2.25s/it, loss=
# Training:  72%|▋| 23/32 [00:54<00:20,  2.25s/it, loss=
# Training:  75%|▊| 24/32 [00:54<00:18,  2.25s/it, loss=
# Training:  75%|▊| 24/32 [00:56<00:18,  2.25s/it, loss=
# Training:  78%|▊| 25/32 [00:56<00:15,  2.25s/it, loss=
# Training:  78%|▊| 25/32 [00:58<00:15,  2.25s/it, loss=
# Training:  81%|▊| 26/32 [00:58<00:13,  2.25s/it, loss=
# Training:  81%|▊| 26/32 [01:00<00:13,  2.25s/it, loss=
# Training:  84%|▊| 27/32 [01:00<00:11,  2.25s/it, loss=
# Training:  84%|▊| 27/32 [01:03<00:11,  2.25s/it, loss=
# Training:  88%|▉| 28/32 [01:03<00:09,  2.25s/it, loss=
# Training:  88%|▉| 28/32 [01:05<00:09,  2.25s/it, loss=
# Training:  91%|▉| 29/32 [01:05<00:06,  2.25s/it, loss=
# Training:  91%|▉| 29/32 [01:07<00:06,  2.25s/it, loss=
# Training:  94%|▉| 30/32 [01:07<00:04,  2.25s/it, loss=
# Training:  94%|▉| 30/32 [01:09<00:04,  2.25s/it, loss=
# Training:  97%|▉| 31/32 [01:09<00:02,  2.25s/it, loss=
# Training:  97%|▉| 31/32 [01:11<00:02,  2.25s/it, loss=
# Training: 100%|█| 32/32 [01:12<00:00,  2.25s/it, loss=
#
# Validation:   0%|               | 0/7 [00:00<?, ?it/s]
# Validation:   0%| | 0/7 [00:00<?, ?it/s, loss=0.2079,
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.97it/s, loss=
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.97it/s, loss=
# Validation:  29%|▎| 2/7 [00:00<00:01,  2.95it/s, loss=
# Validation:  29%|▎| 2/7 [00:01<00:01,  2.95it/s, loss=
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.94it/s, loss=
# Validation:  71%|▋| 5/7 [00:01<00:00,  2.93it/s, loss=
# Validation:  71%|▋| 5/7 [00:02<00:00,  2.93it/s, loss=
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.93it/s, loss=
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.93it/s, loss=
# Validation: 100%|█| 7/7 [00:02<00:00,  2.92it/s, loss=
# Epochs:   6%| | 6/100 [07:27<1:56:58, 74.67s/it, train
# New best model saved with validation F1-score: 0.8681
# Validation metrics - Accuracy: 0.9163, Precision: 0.8680, Recall: 0.8683
# Training:   0%|                | 0/32 [00:00<?, ?it/s]
# Training:   0%| | 0/32 [00:02<?, ?it/s, loss=0.2139, a
# Training:   3%| | 1/32 [00:02<01:09,  2.26s/it, loss=0
# Training:   3%| | 1/32 [00:04<01:09,  2.26s/it, loss=0
# Training:   6%| | 2/32 [00:04<01:07,  2.25s/it, loss=0
# Training:   6%| | 2/32 [00:06<01:07,  2.25s/it, loss=0
# Training:   9%| | 3/32 [00:06<01:05,  2.25s/it, loss=0
# Training:   9%| | 3/32 [00:09<01:05,  2.25s/it, loss=0
# Training:  12%|▏| 4/32 [00:09<01:03,  2.25s/it, loss=0
# Training:  12%|▏| 4/32 [00:11<01:03,  2.25s/it, loss=0
# Training:  16%|▏| 5/32 [00:11<01:00,  2.25s/it, loss=0
# Training:  16%|▏| 5/32 [00:13<01:00,  2.25s/it, loss=0
# Training:  19%|▏| 6/32 [00:13<00:58,  2.25s/it, loss=0
# Training:  19%|▏| 6/32 [00:15<00:58,  2.25s/it, loss=0
# Training:  22%|▏| 7/32 [00:15<00:56,  2.25s/it, loss=0
# Training:  22%|▏| 7/32 [00:18<00:56,  2.25s/it, loss=0
# Training:  25%|▎| 8/32 [00:18<00:54,  2.25s/it, loss=0
# Training:  25%|▎| 8/32 [00:20<00:54,  2.25s/it, loss=0
# Training:  28%|▎| 9/32 [00:20<00:51,  2.25s/it, loss=0
# Training:  28%|▎| 9/32 [00:22<00:51,  2.25s/it, loss=0
# Training:  31%|▎| 10/32 [00:22<00:49,  2.25s/it, loss=
# Training:  31%|▎| 10/32 [00:24<00:49,  2.25s/it, loss=
# Training:  34%|▎| 11/32 [00:24<00:47,  2.25s/it, loss=
# Training:  34%|▎| 11/32 [00:27<00:47,  2.25s/it, loss=
# Training:  38%|▍| 12/32 [00:27<00:45,  2.25s/it, loss=
# Training:  38%|▍| 12/32 [00:29<00:45,  2.25s/it, loss=
# Training:  41%|▍| 13/32 [00:29<00:42,  2.25s/it, loss=
# Training:  41%|▍| 13/32 [00:31<00:42,  2.25s/it, loss=
# Training:  44%|▍| 14/32 [00:31<00:40,  2.25s/it, loss=
# Training:  44%|▍| 14/32 [00:33<00:40,  2.25s/it, loss=
# Training:  47%|▍| 15/32 [00:33<00:38,  2.25s/it, loss=
# Training:  47%|▍| 15/32 [00:36<00:38,  2.25s/it, loss=
# Training:  50%|▌| 16/32 [00:36<00:36,  2.25s/it, loss=
# Training:  50%|▌| 16/32 [00:38<00:36,  2.25s/it, loss=
# Training:  53%|▌| 17/32 [00:38<00:33,  2.25s/it, loss=
# Training:  53%|▌| 17/32 [00:40<00:33,  2.25s/it, loss=
# Training:  56%|▌| 18/32 [00:40<00:31,  2.25s/it, loss=
# Training:  56%|▌| 18/32 [00:42<00:31,  2.25s/it, loss=
# Training:  59%|▌| 19/32 [00:42<00:29,  2.25s/it, loss=
# Training:  59%|▌| 19/32 [00:45<00:29,  2.25s/it, loss=
# Training:  62%|▋| 20/32 [00:45<00:27,  2.25s/it, loss=
# Training:  62%|▋| 20/32 [00:47<00:27,  2.25s/it, loss=
# Training:  66%|▋| 21/32 [00:47<00:24,  2.25s/it, loss=
# Training:  66%|▋| 21/32 [00:49<00:24,  2.25s/it, loss=
# Training:  69%|▋| 22/32 [00:49<00:22,  2.25s/it, loss=
# Training:  69%|▋| 22/32 [00:51<00:22,  2.25s/it, loss=
# Training:  72%|▋| 23/32 [00:51<00:20,  2.25s/it, loss=
# Training:  72%|▋| 23/32 [00:54<00:20,  2.25s/it, loss=
# Training:  75%|▊| 24/32 [00:54<00:18,  2.25s/it, loss=
# Training:  75%|▊| 24/32 [00:56<00:18,  2.25s/it, loss=
# Training:  78%|▊| 25/32 [00:56<00:15,  2.25s/it, loss=
# Training:  78%|▊| 25/32 [00:58<00:15,  2.25s/it, loss=
# Training:  81%|▊| 26/32 [00:58<00:13,  2.25s/it, loss=
# Training:  81%|▊| 26/32 [01:00<00:13,  2.25s/it, loss=
# Training:  84%|▊| 27/32 [01:00<00:11,  2.25s/it, loss=
# Training:  84%|▊| 27/32 [01:03<00:11,  2.25s/it, loss=
# Training:  88%|▉| 28/32 [01:03<00:09,  2.25s/it, loss=
# Training:  88%|▉| 28/32 [01:05<00:09,  2.25s/it, loss=
# Training:  91%|▉| 29/32 [01:05<00:06,  2.25s/it, loss=
# Training:  91%|▉| 29/32 [01:07<00:06,  2.25s/it, loss=
# Training:  94%|▉| 30/32 [01:07<00:04,  2.25s/it, loss=
# Training:  94%|▉| 30/32 [01:09<00:04,  2.25s/it, loss=
# Training:  97%|▉| 31/32 [01:09<00:02,  2.25s/it, loss=
# Training:  97%|▉| 31/32 [01:12<00:02,  2.25s/it, loss=
# Training: 100%|█| 32/32 [01:12<00:00,  2.25s/it, loss=
#
# Validation:   0%|                              | 0/7 [00:00<?, ?it/s]
# Validation:   0%| | 0/7 [00:00<?, ?it/s, loss=0.2154, acc=0.9141, f1=
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.95it/s, loss=0.2154, acc=0.9
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.95it/s, loss=0.2011, acc=0.9
# Validation:  29%|▎| 2/7 [00:00<00:01,  2.94it/s, loss=0.2011, acc=0.9
# Validation:  29%|▎| 2/7 [00:01<00:01,  2.94it/s, loss=0.2354, acc=0.9
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.93it/s, loss=0.2354, acc=0.9
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.93it/s, loss=0.2158, acc=0.9
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.92it/s, loss=0.2158, acc=0.9
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.92it/s, loss=0.2231, acc=0.9
# Validation:  71%|▋| 5/7 [00:01<00:00,  2.92it/s, loss=0.2231, acc=0.9
# Validation:  71%|▋| 5/7 [00:02<00:00,  2.92it/s, loss=0.2331, acc=0.9
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.93it/s, loss=0.2331, acc=0.9
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.93it/s, loss=0.2161, acc=0.9
# Validation: 100%|█| 7/7 [00:02<00:00,  2.91it/s, loss=0.2161, acc=0.9
# Epochs:   7%| | 7/100 [08:42<1:55:36, 74.59s/it, train
# Training:   0%|                               | 0/32 [00:00<?, ?it/s]
# Training:   0%| | 0/32 [00:02<?, ?it/s, loss=0.2096, acc=0.9176, f1=0
# Training:   3%| | 1/32 [00:02<01:09,  2.25s/it, loss=0.2096, acc=0.91
# Training:   3%| | 1/32 [00:04<01:09,  2.25s/it, loss=0.2222, acc=0.91
# Training:   6%| | 2/32 [00:04<01:07,  2.25s/it, loss=0.2222, acc=0.91
# Training:   6%| | 2/32 [00:06<01:07,  2.25s/it, loss=0.2163, acc=0.91
# Training:   9%| | 3/32 [00:06<01:05,  2.25s/it, loss=0.2163, acc=0.91
# Training:   9%| | 3/32 [00:09<01:05,  2.25s/it, loss=0.1995, acc=0.92
# Training:  12%|▏| 4/32 [00:09<01:03,  2.25s/it, loss=0.1995, acc=0.92
# Training:  12%|▏| 4/32 [00:11<01:03,  2.25s/it, loss=0.1979, acc=0.92
# Training:  16%|▏| 5/32 [00:11<01:00,  2.25s/it, loss=0.1979, acc=0.92
# Training:  16%|▏| 5/32 [00:13<01:00,  2.25s/it, loss=0.1974, acc=0.92
# Training:  19%|▏| 6/32 [00:13<00:58,  2.25s/it, loss=0.1974, acc=0.92
# Training:  19%|▏| 6/32 [00:15<00:58,  2.25s/it, loss=0.2098, acc=0.91
# Training:  22%|▏| 7/32 [00:15<00:56,  2.25s/it, loss=0.2098, acc=0.91
# Training:  22%|▏| 7/32 [00:18<00:56,  2.25s/it, loss=0.1860, acc=0.92
# Training:  25%|▎| 8/32 [00:18<00:54,  2.25s/it, loss=0.1860, acc=0.92
# Training:  25%|▎| 8/32 [00:20<00:54,  2.25s/it, loss=0.1855, acc=0.92
# Training:  28%|▎| 9/32 [00:20<00:51,  2.25s/it, loss=0.1855, acc=0.92
# Training:  28%|▎| 9/32 [00:22<00:51,  2.25s/it, loss=0.2005, acc=0.92
# Training:  31%|▎| 10/32 [00:22<00:49,  2.26s/it, loss=0.2005, acc=0.9
# Training:  31%|▎| 10/32 [00:24<00:49,  2.26s/it, loss=0.1864, acc=0.9
# Training:  34%|▎| 11/32 [00:24<00:47,  2.25s/it, loss=0.1864, acc=0.9
# Training:  34%|▎| 11/32 [00:27<00:47,  2.25s/it, loss=0.2057, acc=0.9
# Training:  38%|▍| 12/32 [00:27<00:45,  2.25s/it, loss=0.2057, acc=0.9
# Training:  38%|▍| 12/32 [00:29<00:45,  2.25s/it, loss=0.2136, acc=0.9
# Training:  41%|▍| 13/32 [00:29<00:42,  2.25s/it, loss=0.2136, acc=0.9
# Training:  41%|▍| 13/32 [00:31<00:42,  2.25s/it, loss=0.1840, acc=0.9
# Training:  44%|▍| 14/32 [00:31<00:40,  2.25s/it, loss=0.1840, acc=0.9
# Training:  44%|▍| 14/32 [00:33<00:40,  2.25s/it, loss=0.1892, acc=0.9
# Training:  47%|▍| 15/32 [00:33<00:38,  2.25s/it, loss=0.1892, acc=0.9
# Training:  47%|▍| 15/32 [00:36<00:38,  2.25s/it, loss=0.2551, acc=0.8
# Training:  50%|▌| 16/32 [00:36<00:36,  2.25s/it, loss=0.2551, acc=0.8
# Training:  50%|▌| 16/32 [00:38<00:36,  2.25s/it, loss=0.2060, acc=0.9
# Training:  53%|▌| 17/32 [00:38<00:33,  2.25s/it, loss=0.2060, acc=0.9
# Training:  53%|▌| 17/32 [00:40<00:33,  2.25s/it, loss=0.2002, acc=0.9
# Training:  56%|▌| 18/32 [00:40<00:31,  2.25s/it, loss=0.2002, acc=0.9
# Training:  56%|▌| 18/32 [00:42<00:31,  2.25s/it, loss=0.2011, acc=0.9
# Training:  59%|▌| 19/32 [00:42<00:29,  2.25s/it, loss=0.2011, acc=0.9
# Training:  59%|▌| 19/32 [00:45<00:29,  2.25s/it, loss=0.2124, acc=0.9
# Training:  62%|▋| 20/32 [00:45<00:27,  2.25s/it, loss=0.2124, acc=0.9
# Training:  62%|▋| 20/32 [00:47<00:27,  2.25s/it, loss=0.1854, acc=0.9
# Training:  66%|▋| 21/32 [00:47<00:24,  2.25s/it, loss=0.1854, acc=0.9
# Training:  66%|▋| 21/32 [00:49<00:24,  2.25s/it, loss=0.2015, acc=0.9
# Training:  69%|▋| 22/32 [00:49<00:22,  2.25s/it, loss=0.2015, acc=0.9
# Training:  69%|▋| 22/32 [00:51<00:22,  2.25s/it, loss=0.2158, acc=0.9
# Training:  72%|▋| 23/32 [00:51<00:20,  2.25s/it, loss=0.2158, acc=0.9
# Training:  72%|▋| 23/32 [00:54<00:20,  2.25s/it, loss=0.1947, acc=0.9
# Training:  75%|▊| 24/32 [00:54<00:18,  2.25s/it, loss=0.1947, acc=0.9
# Training:  75%|▊| 24/32 [00:56<00:18,  2.25s/it, loss=0.2030, acc=0.9
# Training:  78%|▊| 25/32 [00:56<00:15,  2.25s/it, loss=0.2030, acc=0.9
# Training:  78%|▊| 25/32 [00:58<00:15,  2.25s/it, loss=0.1874, acc=0.9
# Training:  81%|▊| 26/32 [00:58<00:13,  2.25s/it, loss=0.1874, acc=0.9
# Training:  81%|▊| 26/32 [01:00<00:13,  2.25s/it, loss=0.1930, acc=0.9
# Training:  84%|▊| 27/32 [01:00<00:11,  2.25s/it, loss=0.1930, acc=0.9
# Training:  84%|▊| 27/32 [01:03<00:11,  2.25s/it, loss=0.1894, acc=0.9
# Training:  88%|▉| 28/32 [01:03<00:09,  2.25s/it, loss=0.1894, acc=0.9
# Training:  88%|▉| 28/32 [01:05<00:09,  2.25s/it, loss=0.1899, acc=0.9
# Training:  91%|▉| 29/32 [01:05<00:06,  2.25s/it, loss=0.1899, acc=0.9
# Training:  91%|▉| 29/32 [01:07<00:06,  2.25s/it, loss=0.2090, acc=0.9
# Training:  94%|▉| 30/32 [01:07<00:04,  2.25s/it, loss=0.2090, acc=0.9
# Training:  94%|▉| 30/32 [01:09<00:04,  2.25s/it, loss=0.2008, acc=0.9
# Training:  97%|▉| 31/32 [01:09<00:02,  2.25s/it, loss=0.2008, acc=0.9
# Training:  97%|▉| 31/32 [01:12<00:02,  2.25s/it, loss=0.1974, acc=0.9
# Training: 100%|█| 32/32 [01:12<00:00,  2.25s/it, loss=0.1974, acc=0.9
#
# Validation:   0%|                              | 0/7 [00:00<?, ?it/s]
# Validation:   0%| | 0/7 [00:00<?, ?it/s, loss=0.2038, acc=0.9208, f1=
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.95it/s, loss=0.2038, acc=0.9
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.95it/s, loss=0.1816, acc=0.9
# Validation:  29%|▎| 2/7 [00:00<00:01,  2.94it/s, loss=0.1816, acc=0.9
# Validation:  29%|▎| 2/7 [00:01<00:01,  2.94it/s, loss=0.2200, acc=0.9
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.93it/s, loss=0.2200, acc=0.9
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.93it/s, loss=0.2073, acc=0.9
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.93it/s, loss=0.2073, acc=0.9
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.93it/s, loss=0.2040, acc=0.9
# Validation:  71%|▋| 5/7 [00:01<00:00,  2.93it/s, loss=0.2040, acc=0.9
# Validation:  71%|▋| 5/7 [00:02<00:00,  2.93it/s, loss=0.2230, acc=0.9
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.93it/s, loss=0.2230, acc=0.9
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.93it/s, loss=0.1946, acc=0.9
# Validation: 100%|█| 7/7 [00:02<00:00,  2.92it/s, loss=0.1946, acc=0.9
# Epochs:   8%| | 8/100 [09:57<1:54:25, 74.62s/it, train
# New best model saved with validation F1-score: 0.8748
# Validation metrics - Accuracy: 0.9216, Precision: 0.8890, Recall: 0.8612
# Training:   0%|                               | 0/32 [00:00<?, ?it/s]
# Training:   0%| | 0/32 [00:02<?, ?it/s, loss=0.1934, acc=0.9252, f1=0
# Training:   3%| | 1/32 [00:02<01:09,  2.26s/it, loss=0.1934, acc=0.92
# Training:   3%| | 1/32 [00:04<01:09,  2.26s/it, loss=0.2109, acc=0.91
# Training:   6%| | 2/32 [00:04<01:07,  2.26s/it, loss=0.2109, acc=0.91
# Training:   6%| | 2/32 [00:06<01:07,  2.26s/it, loss=0.2135, acc=0.91
# Training:   9%| | 3/32 [00:06<01:05,  2.26s/it, loss=0.2135, acc=0.91
# Training:   9%| | 3/32 [00:09<01:05,  2.26s/it, loss=0.1928, acc=0.92
# Training:  12%|▏| 4/32 [00:09<01:03,  2.25s/it, loss=0.1928, acc=0.92
# Training:  12%|▏| 4/32 [00:11<01:03,  2.25s/it, loss=0.1893, acc=0.92
# Training:  16%|▏| 5/32 [00:11<01:00,  2.25s/it, loss=0.1893, acc=0.92
# Training:  16%|▏| 5/32 [00:13<01:00,  2.25s/it, loss=0.1919, acc=0.92
# Training:  19%|▏| 6/32 [00:13<00:58,  2.25s/it, loss=0.1919, acc=0.92
# Training:  19%|▏| 6/32 [00:15<00:58,  2.25s/it, loss=0.2007, acc=0.92
# Training:  22%|▏| 7/32 [00:15<00:56,  2.25s/it, loss=0.2007, acc=0.92
# Training:  22%|▏| 7/32 [00:18<00:56,  2.25s/it, loss=0.1807, acc=0.92
# Training:  25%|▎| 8/32 [00:18<00:54,  2.25s/it, loss=0.1807, acc=0.92
# Training:  25%|▎| 8/32 [00:20<00:54,  2.25s/it, loss=0.1781, acc=0.93
# Training:  28%|▎| 9/32 [00:20<00:51,  2.25s/it, loss=0.1781, acc=0.93
# Training:  28%|▎| 9/32 [00:22<00:51,  2.25s/it, loss=0.1944, acc=0.92
# Training:  31%|▎| 10/32 [00:22<00:49,  2.25s/it, loss=0.1944, acc=0.9
# Training:  31%|▎| 10/32 [00:24<00:49,  2.25s/it, loss=0.1806, acc=0.9
# Training:  34%|▎| 11/32 [00:24<00:47,  2.25s/it, loss=0.1806, acc=0.9
# Training:  34%|▎| 11/32 [00:27<00:47,  2.25s/it, loss=0.2009, acc=0.9
# Training:  38%|▍| 12/32 [00:27<00:45,  2.25s/it, loss=0.2009, acc=0.9
# Training:  38%|▍| 12/32 [00:29<00:45,  2.25s/it, loss=0.2053, acc=0.9
# Training:  41%|▍| 13/32 [00:29<00:42,  2.25s/it, loss=0.2053, acc=0.9
# Training:  41%|▍| 13/32 [00:31<00:42,  2.25s/it, loss=0.1776, acc=0.9
# Training:  44%|▍| 14/32 [00:31<00:40,  2.25s/it, loss=0.1776, acc=0.9
# Training:  44%|▍| 14/32 [00:33<00:40,  2.25s/it, loss=0.1847, acc=0.9
# Training:  47%|▍| 15/32 [00:33<00:38,  2.25s/it, loss=0.1847, acc=0.9
# Training:  47%|▍| 15/32 [00:36<00:38,  2.25s/it, loss=0.2373, acc=0.9
# Training:  50%|▌| 16/32 [00:36<00:36,  2.25s/it, loss=0.2373, acc=0.9
# Training:  50%|▌| 16/32 [00:38<00:36,  2.25s/it, loss=0.1955, acc=0.9
# Training:  53%|▌| 17/32 [00:38<00:33,  2.25s/it, loss=0.1955, acc=0.9
# Training:  53%|▌| 17/32 [00:40<00:33,  2.25s/it, loss=0.1938, acc=0.9
# Training:  56%|▌| 18/32 [00:40<00:31,  2.25s/it, loss=0.1938, acc=0.9
# Training:  56%|▌| 18/32 [00:42<00:31,  2.25s/it, loss=0.1941, acc=0.9
# Training:  59%|▌| 19/32 [00:42<00:29,  2.26s/it, loss=0.1941, acc=0.9
# Training:  59%|▌| 19/32 [00:45<00:29,  2.26s/it, loss=0.2055, acc=0.9
# Training:  62%|▋| 20/32 [00:45<00:27,  2.26s/it, loss=0.2055, acc=0.9
# Training:  62%|▋| 20/32 [00:47<00:27,  2.26s/it, loss=0.1811, acc=0.9
# Training:  66%|▋| 21/32 [00:47<00:24,  2.26s/it, loss=0.1811, acc=0.9
# Training:  66%|▋| 21/32 [00:49<00:24,  2.26s/it, loss=0.1921, acc=0.9
# Training:  69%|▋| 22/32 [00:49<00:22,  2.26s/it, loss=0.1921, acc=0.9
# Training:  69%|▋| 22/32 [00:51<00:22,  2.26s/it, loss=0.2058, acc=0.9
# Training:  72%|▋| 23/32 [00:51<00:20,  2.26s/it, loss=0.2058, acc=0.9
# Training:  72%|▋| 23/32 [00:54<00:20,  2.26s/it, loss=0.1903, acc=0.9
# Training:  75%|▊| 24/32 [00:54<00:18,  2.26s/it, loss=0.1903, acc=0.9
# Training:  75%|▊| 24/32 [00:56<00:18,  2.26s/it, loss=0.1977, acc=0.9
# Training:  78%|▊| 25/32 [00:56<00:15,  2.26s/it, loss=0.1977, acc=0.9
# Training:  78%|▊| 25/32 [00:58<00:15,  2.26s/it, loss=0.1816, acc=0.9
# Training:  81%|▊| 26/32 [00:58<00:13,  2.26s/it, loss=0.1816, acc=0.9
# Training:  81%|▊| 26/32 [01:00<00:13,  2.26s/it, loss=0.1832, acc=0.9
# Training:  84%|▊| 27/32 [01:00<00:11,  2.26s/it, loss=0.1832, acc=0.9
# Training:  84%|▊| 27/32 [01:03<00:11,  2.26s/it, loss=0.1781, acc=0.9
# Training:  88%|▉| 28/32 [01:03<00:09,  2.26s/it, loss=0.1781, acc=0.9
# Training:  88%|▉| 28/32 [01:05<00:09,  2.26s/it, loss=0.1777, acc=0.9
# Training:  91%|▉| 29/32 [01:05<00:06,  2.26s/it, loss=0.1777, acc=0.9
# Training:  91%|▉| 29/32 [01:07<00:06,  2.26s/it, loss=0.2041, acc=0.9
# Training:  94%|▉| 30/32 [01:07<00:04,  2.26s/it, loss=0.2041, acc=0.9
# Training:  94%|▉| 30/32 [01:09<00:04,  2.26s/it, loss=0.1906, acc=0.9
# Training:  97%|▉| 31/32 [01:09<00:02,  2.26s/it, loss=0.1906, acc=0.9
# Training:  97%|▉| 31/32 [01:12<00:02,  2.26s/it, loss=0.1871, acc=0.9
# Training: 100%|█| 32/32 [01:12<00:00,  2.25s/it, loss=0.1871, acc=0.9
#
# Validation:   0%|                              | 0/7 [00:00<?, ?it/s]
# Validation:   0%| | 0/7 [00:00<?, ?it/s, loss=0.2060, acc=0.9209, f1=
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.96it/s, loss=0.2060, acc=0.9
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.96it/s, loss=0.1827, acc=0.9
# Validation:  29%|▎| 2/7 [00:00<00:01,  2.94it/s, loss=0.1827, acc=0.9
# Validation:  29%|▎| 2/7 [00:01<00:01,  2.94it/s, loss=0.2174, acc=0.9
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.93it/s, loss=0.2174, acc=0.9
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.93it/s, loss=0.2050, acc=0.9
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.93it/s, loss=0.2050, acc=0.9
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.93it/s, loss=0.2093, acc=0.9
# Validation:  71%|▋| 5/7 [00:01<00:00,  2.93it/s, loss=0.2093, acc=0.9
# Validation:  71%|▋| 5/7 [00:02<00:00,  2.93it/s, loss=0.2208, acc=0.9
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.92it/s, loss=0.2208, acc=0.9
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.92it/s, loss=0.1974, acc=0.9
# Validation: 100%|█| 7/7 [00:02<00:00,  2.92it/s, loss=0.1974, acc=0.9
# Epochs:   9%| | 9/100 [11:11<1:53:06, 74.57s/it, train
# Training:   0%|                               | 0/32 [00:00<?, ?it/s]
# Training:   0%| | 0/32 [00:02<?, ?it/s, loss=0.1890, acc=0.9264, f1=0
# Training:   3%| | 1/32 [00:02<01:09,  2.25s/it, loss=0.1890, acc=0.92
# Training:   3%| | 1/32 [00:04<01:09,  2.25s/it, loss=0.2052, acc=0.91
# Training:   6%| | 2/32 [00:04<01:07,  2.26s/it, loss=0.2052, acc=0.91
# Training:   6%| | 2/32 [00:06<01:07,  2.26s/it, loss=0.2099, acc=0.91
# Training:   9%| | 3/32 [00:06<01:05,  2.26s/it, loss=0.2099, acc=0.91
# Training:   9%| | 3/32 [00:09<01:05,  2.26s/it, loss=0.1929, acc=0.92
# Training:  12%|▏| 4/32 [00:09<01:03,  2.26s/it, loss=0.1929, acc=0.92
# Training:  12%|▏| 4/32 [00:11<01:03,  2.26s/it, loss=0.1889, acc=0.92
# Training:  16%|▏| 5/32 [00:11<01:00,  2.26s/it, loss=0.1889, acc=0.92
# Training:  16%|▏| 5/32 [00:13<01:00,  2.26s/it, loss=0.1876, acc=0.92
# Training:  19%|▏| 6/32 [00:13<00:58,  2.26s/it, loss=0.1876, acc=0.92
# Training:  19%|▏| 6/32 [00:15<00:58,  2.26s/it, loss=0.2004, acc=0.92
# Training:  22%|▏| 7/32 [00:15<00:56,  2.26s/it, loss=0.2004, acc=0.92
# Training:  22%|▏| 7/32 [00:18<00:56,  2.26s/it, loss=0.1798, acc=0.92
# Training:  25%|▎| 8/32 [00:18<00:54,  2.25s/it, loss=0.1798, acc=0.92
# Training:  25%|▎| 8/32 [00:20<00:54,  2.25s/it, loss=0.1719, acc=0.93
# Training:  28%|▎| 9/32 [00:20<00:51,  2.26s/it, loss=0.1719, acc=0.93
# Training:  28%|▎| 9/32 [00:22<00:51,  2.26s/it, loss=0.1938, acc=0.92
# Training:  31%|▎| 10/32 [00:22<00:49,  2.26s/it, loss=0.1938, acc=0.9
# Training:  31%|▎| 10/32 [00:24<00:49,  2.26s/it, loss=0.1795, acc=0.9
# Training:  34%|▎| 11/32 [00:24<00:47,  2.26s/it, loss=0.1795, acc=0.9
# Training:  34%|▎| 11/32 [00:27<00:47,  2.26s/it, loss=0.2065, acc=0.9
# Training:  38%|▍| 12/32 [00:27<00:45,  2.26s/it, loss=0.2065, acc=0.9
# Training:  38%|▍| 12/32 [00:29<00:45,  2.26s/it, loss=0.2129, acc=0.9
# Training:  41%|▍| 13/32 [00:29<00:42,  2.26s/it, loss=0.2129, acc=0.9
# Training:  41%|▍| 13/32 [00:31<00:42,  2.26s/it, loss=0.1738, acc=0.9
# Training:  44%|▍| 14/32 [00:31<00:40,  2.26s/it, loss=0.1738, acc=0.9
# Training:  44%|▍| 14/32 [00:33<00:40,  2.26s/it, loss=0.1825, acc=0.9
# Training:  47%|▍| 15/32 [00:33<00:38,  2.26s/it, loss=0.1825, acc=0.9
# Training:  47%|▍| 15/32 [00:36<00:38,  2.26s/it, loss=0.2428, acc=0.9
# Training:  50%|▌| 16/32 [00:36<00:36,  2.26s/it, loss=0.2428, acc=0.9
# Training:  50%|▌| 16/32 [00:38<00:36,  2.26s/it, loss=0.2137, acc=0.9
# Training:  53%|▌| 17/32 [00:38<00:33,  2.26s/it, loss=0.2137, acc=0.9
# Training:  53%|▌| 17/32 [00:40<00:33,  2.26s/it, loss=0.1923, acc=0.9
# Training:  56%|▌| 18/32 [00:40<00:31,  2.25s/it, loss=0.1923, acc=0.9
# Training:  56%|▌| 18/32 [00:42<00:31,  2.25s/it, loss=0.1939, acc=0.9
# Training:  59%|▌| 19/32 [00:42<00:29,  2.25s/it, loss=0.1939, acc=0.9
# Training:  59%|▌| 19/32 [00:45<00:29,  2.25s/it, loss=0.2060, acc=0.9
# Training:  62%|▋| 20/32 [00:45<00:27,  2.25s/it, loss=0.2060, acc=0.9
# Training:  62%|▋| 20/32 [00:47<00:27,  2.25s/it, loss=0.1820, acc=0.9
# Training:  66%|▋| 21/32 [00:47<00:24,  2.25s/it, loss=0.1820, acc=0.9
# Training:  66%|▋| 21/32 [00:49<00:24,  2.25s/it, loss=0.1948, acc=0.9
# Training:  69%|▋| 22/32 [00:49<00:22,  2.25s/it, loss=0.1948, acc=0.9
# Training:  69%|▋| 22/32 [00:51<00:22,  2.25s/it, loss=0.2094, acc=0.9
# Training:  72%|▋| 23/32 [00:51<00:20,  2.25s/it, loss=0.2094, acc=0.9
# Training:  72%|▋| 23/32 [00:54<00:20,  2.25s/it, loss=0.1898, acc=0.9
# Training:  75%|▊| 24/32 [00:54<00:18,  2.25s/it, loss=0.1898, acc=0.9
# Training:  75%|▊| 24/32 [00:56<00:18,  2.25s/it, loss=0.1950, acc=0.9
# Training:  78%|▊| 25/32 [00:56<00:15,  2.25s/it, loss=0.1950, acc=0.9
# Training:  78%|▊| 25/32 [00:58<00:15,  2.25s/it, loss=0.1831, acc=0.9
# Training:  81%|▊| 26/32 [00:58<00:13,  2.25s/it, loss=0.1831, acc=0.9
# Training:  81%|▊| 26/32 [01:00<00:13,  2.25s/it, loss=0.1816, acc=0.9
# Training:  84%|▊| 27/32 [01:00<00:11,  2.25s/it, loss=0.1816, acc=0.9
# Training:  84%|▊| 27/32 [01:03<00:11,  2.25s/it, loss=0.1771, acc=0.9
# Training:  88%|▉| 28/32 [01:03<00:09,  2.25s/it, loss=0.1771, acc=0.9
# Training:  88%|▉| 28/32 [01:05<00:09,  2.25s/it, loss=0.2014, acc=0.9
# Training:  91%|▉| 29/32 [01:05<00:06,  2.25s/it, loss=0.2014, acc=0.9
# Training:  91%|▉| 29/32 [01:07<00:06,  2.25s/it, loss=0.2016, acc=0.9
# Training:  94%|▉| 30/32 [01:07<00:04,  2.25s/it, loss=0.2016, acc=0.9
# ...
# Training:  25%|▎| 8/32 [00:20<00:54,  2.25s/it,
# Training:  28%|▎| 9/32 [00:20<00:51,  2.25s/it,
# Training:  28%|▎| 9/32 [00:22<00:51,  2.25s/it,
# Training:  31%|▎| 10/32 [00:22<00:49,  2.25s/it
# Training:  31%|▎| 10/32 [00:24<00:49,  2.25s/it
# Training:  34%|▎| 11/32 [00:24<00:47,  2.25s/it
# Training:  34%|▎| 11/32 [00:27<00:47,  2.25s/it
# Training:  38%|▍| 12/32 [00:27<00:45,  2.25s/it
# Training:  38%|▍| 12/32 [00:29<00:45,  2.25s/it
# Training:  41%|▍| 13/32 [00:29<00:42,  2.25s/it
# Training:  41%|▍| 13/32 [00:31<00:42,  2.25s/it
# Training:  44%|▍| 14/32 [00:31<00:40,  2.25s/it
# Training:  44%|▍| 14/32 [00:33<00:40,  2.25s/it
# Training:  47%|▍| 15/32 [00:33<00:38,  2.26s/it
# Training:  47%|▍| 15/32 [00:36<00:38,  2.26s/it
# Training:  50%|▌| 16/32 [00:36<00:36,  2.26s/it
# Training:  50%|▌| 16/32 [00:38<00:36,  2.26s/it
# Training:  53%|▌| 17/32 [00:38<00:33,  2.26s/it
# Training:  53%|▌| 17/32 [00:40<00:33,  2.26s/it
# Training:  56%|▌| 18/32 [00:40<00:31,  2.25s/it
# Training:  56%|▌| 18/32 [00:42<00:31,  2.25s/it
# Training:  59%|▌| 19/32 [00:42<00:29,  2.25s/it
# Training:  59%|▌| 19/32 [00:45<00:29,  2.25s/it
# Training:  62%|▋| 20/32 [00:45<00:27,  2.25s/it
# Training:  62%|▋| 20/32 [00:47<00:27,  2.25s/it
# Training:  66%|▋| 21/32 [00:47<00:24,  2.25s/it
# Training:  66%|▋| 21/32 [00:49<00:24,  2.25s/it
# Training:  69%|▋| 22/32 [00:49<00:22,  2.25s/it
# Training:  69%|▋| 22/32 [00:51<00:22,  2.25s/it
# Training:  72%|▋| 23/32 [00:51<00:20,  2.25s/it
# Training:  72%|▋| 23/32 [00:54<00:20,  2.25s/it
# Training:  75%|▊| 24/32 [00:54<00:18,  2.25s/it
# Training:  75%|▊| 24/32 [00:56<00:18,  2.25s/it
# Training:  78%|▊| 25/32 [00:56<00:15,  2.25s/it
# Training:  78%|▊| 25/32 [00:58<00:15,  2.25s/it
# Training:  81%|▊| 26/32 [00:58<00:13,  2.25s/it
# Training:  81%|▊| 26/32 [01:00<00:13,  2.25s/it
# Training:  84%|▊| 27/32 [01:00<00:11,  2.25s/it
# Training:  84%|▊| 27/32 [01:03<00:11,  2.25s/it
# Training:  88%|▉| 28/32 [01:03<00:09,  2.25s/it
# Training:  88%|▉| 28/32 [01:05<00:09,  2.25s/it
# Training:  91%|▉| 29/32 [01:05<00:06,  2.25s/it
# Training:  91%|▉| 29/32 [01:07<00:06,  2.25s/it
# Training:  94%|▉| 30/32 [01:07<00:04,  2.25s/it
# Training:  94%|▉| 30/32 [01:09<00:04,  2.25s/it
# Training:  97%|▉| 31/32 [01:09<00:02,  2.25s/it
# Training:  97%|▉| 31/32 [01:12<00:02,  2.25s/it
# Training: 100%|█| 32/32 [01:12<00:00,  2.25s/it
#
# Validation:   0%|        | 0/7 [00:00<?, ?it/s]
# Validation:   0%| | 0/7 [00:00<?, ?it/s, loss=0
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.93it/s
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.93it/s
# Validation:  29%|▎| 2/7 [00:00<00:01,  2.92it/s
# Validation:  29%|▎| 2/7 [00:01<00:01,  2.92it/s
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.92it/s
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.92it/s
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.92it/s
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.92it/s
# Validation:  71%|▋| 5/7 [00:01<00:00,  2.91it/s
# Validation:  71%|▋| 5/7 [00:02<00:00,  2.91it/s
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.92it/s
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.92it/s
# Validation: 100%|█| 7/7 [00:02<00:00,  2.91it/s
# Epochs:  17%|▏| 17/100 [21:07<1:43:04, 74.51s/it, trai
# Training:   0%|         | 0/32 [00:00<?, ?it/s]
# Training:   0%| | 0/32 [00:02<?, ?it/s, loss=0.
# Training:   3%| | 1/32 [00:02<01:09,  2.25s/it,
# Training:   3%| | 1/32 [00:04<01:09,  2.25s/it,
# Training:   6%| | 2/32 [00:04<01:07,  2.25s/it,
# Training:   6%| | 2/32 [00:06<01:07,  2.25s/it,
# Training:   9%| | 3/32 [00:06<01:05,  2.25s/it,
# Training:   9%| | 3/32 [00:09<01:05,  2.25s/it,
# Training:  12%|▏| 4/32 [00:09<01:03,  2.25s/it,
# Training:  12%|▏| 4/32 [00:11<01:03,  2.25s/it,
# Training:  16%|▏| 5/32 [00:11<01:00,  2.25s/it,
# Training:  16%|▏| 5/32 [00:13<01:00,  2.25s/it,
# Training:  19%|▏| 6/32 [00:13<00:58,  2.25s/it,
# Training:  19%|▏| 6/32 [00:15<00:58,  2.25s/it,
# Training:  22%|▏| 7/32 [00:15<00:56,  2.25s/it,
# Training:  22%|▏| 7/32 [00:18<00:56,  2.25s/it,
# Training:  25%|▎| 8/32 [00:18<00:54,  2.26s/it,
# Training:  25%|▎| 8/32 [00:20<00:54,  2.26s/it,
# Training:  28%|▎| 9/32 [00:20<00:51,  2.26s/it,
# Training:  28%|▎| 9/32 [00:22<00:51,  2.26s/it,
# Training:  31%|▎| 10/32 [00:22<00:49,  2.26s/it
# Training:  31%|▎| 10/32 [00:24<00:49,  2.26s/it
# Training:  34%|▎| 11/32 [00:24<00:47,  2.26s/it
# Training:  34%|▎| 11/32 [00:27<00:47,  2.26s/it
# Training:  38%|▍| 12/32 [00:27<00:45,  2.26s/it
# Training:  38%|▍| 12/32 [00:29<00:45,  2.26s/it
# Training:  41%|▍| 13/32 [00:29<00:42,  2.25s/it
# Training:  41%|▍| 13/32 [00:31<00:42,  2.25s/it
# Training:  44%|▍| 14/32 [00:31<00:40,  2.25s/it
# Training:  44%|▍| 14/32 [00:33<00:40,  2.25s/it
# Training:  47%|▍| 15/32 [00:33<00:38,  2.25s/it
# Training:  47%|▍| 15/32 [00:36<00:38,  2.25s/it
# Training:  50%|▌| 16/32 [00:36<00:36,  2.25s/it
# Training:  50%|▌| 16/32 [00:38<00:36,  2.25s/it
# Training:  53%|▌| 17/32 [00:38<00:33,  2.25s/it
# Training:  53%|▌| 17/32 [00:40<00:33,  2.25s/it
# Training:  56%|▌| 18/32 [00:40<00:31,  2.25s/it
# Training:  56%|▌| 18/32 [00:42<00:31,  2.25s/it
# Training:  59%|▌| 19/32 [00:42<00:29,  2.25s/it
# Training:  59%|▌| 19/32 [00:45<00:29,  2.25s/it
# Training:  62%|▋| 20/32 [00:45<00:27,  2.25s/it
# Training:  62%|▋| 20/32 [00:47<00:27,  2.25s/it
# Training:  66%|▋| 21/32 [00:47<00:24,  2.25s/it
# Training:  66%|▋| 21/32 [00:49<00:24,  2.25s/it
# Training:  69%|▋| 22/32 [00:49<00:22,  2.25s/it
# Training:  69%|▋| 22/32 [00:51<00:22,  2.25s/it
# Training:  72%|▋| 23/32 [00:51<00:20,  2.25s/it
# Training:  72%|▋| 23/32 [00:54<00:20,  2.25s/it
# Training:  75%|▊| 24/32 [00:54<00:18,  2.25s/it
# Training:  75%|▊| 24/32 [00:56<00:18,  2.25s/it
# Training:  78%|▊| 25/32 [00:56<00:15,  2.25s/it
# Training:  78%|▊| 25/32 [00:58<00:15,  2.25s/it
# Training:  81%|▊| 26/32 [00:58<00:13,  2.25s/it
# Training:  81%|▊| 26/32 [01:00<00:13,  2.25s/it
# Training:  84%|▊| 27/32 [01:00<00:11,  2.25s/it
# Training:  84%|▊| 27/32 [01:03<00:11,  2.25s/it
# Training:  88%|▉| 28/32 [01:03<00:09,  2.25s/it
# Training:  88%|▉| 28/32 [01:05<00:09,  2.25s/it
# Training:  91%|▉| 29/32 [01:05<00:06,  2.25s/it
# Training:  91%|▉| 29/32 [01:07<00:06,  2.25s/it
# Training:  94%|▉| 30/32 [01:07<00:04,  2.25s/it
# Training:  94%|▉| 30/32 [01:09<00:04,  2.25s/it
# Training:  97%|▉| 31/32 [01:09<00:02,  2.25s/it
# Training:  97%|▉| 31/32 [01:12<00:02,  2.25s/it
# Training: 100%|█| 32/32 [01:12<00:00,  2.25s/it
#
# Validation:   0%|                               | 0/7 [00:00<?, ?it/s]
# Validation:   0%| | 0/7 [00:00<?, ?it/s, loss=0.2116, acc=0.9154, f1=0
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.94it/s, loss=0.2116, acc=0.91
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.94it/s, loss=0.1812, acc=0.93
# Validation:  29%|▎| 2/7 [00:00<00:01,  2.92it/s, loss=0.1812, acc=0.93
# Validation:  29%|▎| 2/7 [00:01<00:01,  2.92it/s, loss=0.2214, acc=0.91
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.91it/s, loss=0.2214, acc=0.91
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.91it/s, loss=0.2100, acc=0.91
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.92it/s, loss=0.2100, acc=0.91
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.92it/s, loss=0.1916, acc=0.92
# Validation:  71%|▋| 5/7 [00:01<00:00,  2.92it/s, loss=0.1916, acc=0.92
# Validation:  71%|▋| 5/7 [00:02<00:00,  2.92it/s, loss=0.2252, acc=0.91
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.91it/s, loss=0.2252, acc=0.91
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.91it/s, loss=0.1987, acc=0.92
# Validation: 100%|█| 7/7 [00:02<00:00,  2.90it/s, loss=0.1987, acc=0.92
# Epochs:  18%|▏| 18/100 [22:22<1:41:47, 74.49s/it, trai
# Training:   0%|                                | 0/32 [00:00<?, ?it/s]
# Training:   0%| | 0/32 [00:02<?, ?it/s, loss=0.1732, acc=0.9313, f1=0.
# Training:   3%| | 1/32 [00:02<01:09,  2.25s/it, loss=0.1732, acc=0.931
# Training:   3%| | 1/32 [00:04<01:09,  2.25s/it, loss=0.1848, acc=0.926
# Training:   6%| | 2/32 [00:04<01:07,  2.25s/it, loss=0.1848, acc=0.926
# Training:   6%| | 2/32 [00:06<01:07,  2.25s/it, loss=0.1835, acc=0.929
# Training:   9%| | 3/32 [00:06<01:05,  2.25s/it, loss=0.1835, acc=0.929
# Training:   9%| | 3/32 [00:09<01:05,  2.25s/it, loss=0.1710, acc=0.932
# Training:  12%|▏| 4/32 [00:09<01:03,  2.25s/it, loss=0.1710, acc=0.932
# Training:  12%|▏| 4/32 [00:11<01:03,  2.25s/it, loss=0.1634, acc=0.936
# Training:  16%|▏| 5/32 [00:11<01:00,  2.25s/it, loss=0.1634, acc=0.936
# Training:  16%|▏| 5/32 [00:13<01:00,  2.25s/it, loss=0.1621, acc=0.935
# Training:  19%|▏| 6/32 [00:13<00:58,  2.25s/it, loss=0.1621, acc=0.935
# Training:  19%|▏| 6/32 [00:15<00:58,  2.25s/it, loss=0.1804, acc=0.928
# Training:  22%|▏| 7/32 [00:15<00:56,  2.25s/it, loss=0.1804, acc=0.928
# Training:  22%|▏| 7/32 [00:18<00:56,  2.25s/it, loss=0.1638, acc=0.934
# Training:  25%|▎| 8/32 [00:18<00:54,  2.26s/it, loss=0.1638, acc=0.934
# Training:  25%|▎| 8/32 [00:20<00:54,  2.26s/it, loss=0.1462, acc=0.942
# Training:  28%|▎| 9/32 [00:20<00:51,  2.26s/it, loss=0.1462, acc=0.942
# Training:  28%|▎| 9/32 [00:22<00:51,  2.26s/it, loss=0.1724, acc=0.930
# Training:  31%|▎| 10/32 [00:22<00:49,  2.25s/it, loss=0.1724, acc=0.93
# Training:  31%|▎| 10/32 [00:24<00:49,  2.25s/it, loss=0.1568, acc=0.94
# Training:  34%|▎| 11/32 [00:24<00:47,  2.25s/it, loss=0.1568, acc=0.94
# Training:  34%|▎| 11/32 [00:27<00:47,  2.25s/it, loss=0.1778, acc=0.92
# Training:  38%|▍| 12/32 [00:27<00:45,  2.25s/it, loss=0.1778, acc=0.92
# Training:  38%|▍| 12/32 [00:29<00:45,  2.25s/it, loss=0.1812, acc=0.92
# Training:  41%|▍| 13/32 [00:29<00:42,  2.25s/it, loss=0.1812, acc=0.92
# Training:  41%|▍| 13/32 [00:31<00:42,  2.25s/it, loss=0.1507, acc=0.94
# Training:  44%|▍| 14/32 [00:31<00:40,  2.25s/it, loss=0.1507, acc=0.94
# Training:  44%|▍| 14/32 [00:33<00:40,  2.25s/it, loss=0.1610, acc=0.93
# Training:  47%|▍| 15/32 [00:33<00:38,  2.25s/it, loss=0.1610, acc=0.93
# Training:  47%|▍| 15/32 [00:36<00:38,  2.25s/it, loss=0.2260, acc=0.90
# Training:  50%|▌| 16/32 [00:36<00:36,  2.25s/it, loss=0.2260, acc=0.90
# Training:  50%|▌| 16/32 [00:38<00:36,  2.25s/it, loss=0.1768, acc=0.92
# Training:  53%|▌| 17/32 [00:38<00:33,  2.25s/it, loss=0.1768, acc=0.92
# Training:  53%|▌| 17/32 [00:40<00:33,  2.25s/it, loss=0.1716, acc=0.92
# Training:  56%|▌| 18/32 [00:40<00:31,  2.25s/it, loss=0.1716, acc=0.92
# Training:  56%|▌| 18/32 [00:42<00:31,  2.25s/it, loss=0.1766, acc=0.92
# Training:  59%|▌| 19/32 [00:42<00:29,  2.25s/it, loss=0.1766, acc=0.92
# Training:  59%|▌| 19/32 [00:45<00:29,  2.25s/it, loss=0.1887, acc=0.92
# Training:  62%|▋| 20/32 [00:45<00:27,  2.26s/it, loss=0.1887, acc=0.92
# Training:  62%|▋| 20/32 [00:47<00:27,  2.26s/it, loss=0.1688, acc=0.93
# Training:  66%|▋| 21/32 [00:47<00:24,  2.25s/it, loss=0.1688, acc=0.93
# Training:  66%|▋| 21/32 [00:49<00:24,  2.25s/it, loss=0.1716, acc=0.93
# Training:  69%|▋| 22/32 [00:49<00:22,  2.25s/it, loss=0.1716, acc=0.93
# Training:  69%|▋| 22/32 [00:51<00:22,  2.25s/it, loss=0.1867, acc=0.92
# Training:  72%|▋| 23/32 [00:51<00:20,  2.25s/it, loss=0.1867, acc=0.92
# Training:  72%|▋| 23/32 [00:54<00:20,  2.25s/it, loss=0.1814, acc=0.92
# Training:  75%|▊| 24/32 [00:54<00:18,  2.25s/it, loss=0.1814, acc=0.92
# Training:  75%|▊| 24/32 [00:56<00:18,  2.25s/it, loss=0.1836, acc=0.92
# Training:  78%|▊| 25/32 [00:56<00:15,  2.25s/it, loss=0.1836, acc=0.92
# Training:  78%|▊| 25/32 [00:58<00:15,  2.25s/it, loss=0.1626, acc=0.93
# Training:  81%|▊| 26/32 [00:58<00:13,  2.25s/it, loss=0.1626, acc=0.93
# Training:  81%|▊| 26/32 [01:00<00:13,  2.25s/it, loss=0.1668, acc=0.93
# Training:  84%|▊| 27/32 [01:00<00:11,  2.25s/it, loss=0.1668, acc=0.93
# Training:  84%|▊| 27/32 [01:03<00:11,  2.25s/it, loss=0.1714, acc=0.93
# Training:  88%|▉| 28/32 [01:03<00:09,  2.25s/it, loss=0.1714, acc=0.93
# Training:  88%|▉| 28/32 [01:05<00:09,  2.25s/it, loss=0.1623, acc=0.93
# Training:  91%|▉| 29/32 [01:05<00:06,  2.25s/it, loss=0.1623, acc=0.93
# Training:  91%|▉| 29/32 [01:07<00:06,  2.25s/it, loss=0.1832, acc=0.92
# Training:  94%|▉| 30/32 [01:07<00:04,  2.25s/it, loss=0.1832, acc=0.92
# Training:  94%|▉| 30/32 [01:09<00:04,  2.25s/it, loss=0.1630, acc=0.93
# Training:  97%|▉| 31/32 [01:09<00:02,  2.25s/it, loss=0.1630, acc=0.93
# Training:  97%|▉| 31/32 [01:12<00:02,  2.25s/it, loss=0.1636, acc=0.93
# Training: 100%|█| 32/32 [01:12<00:00,  2.25s/it, loss=0.1636, acc=0.93
#
# Validation:   0%|                               | 0/7 [00:00<?, ?it/s]
# Validation:   0%| | 0/7 [00:00<?, ?it/s, loss=0.2848, acc=0.8789, f1=0
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.93it/s, loss=0.2848, acc=0.87
# Validation:  14%|▏| 1/7 [00:00<00:02,  2.93it/s, loss=0.2309, acc=0.90
# Validation:  29%|▎| 2/7 [00:00<00:01,  2.92it/s, loss=0.2309, acc=0.90
# Validation:  29%|▎| 2/7 [00:01<00:01,  2.92it/s, loss=0.2565, acc=0.89
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.92it/s, loss=0.2565, acc=0.89
# Validation:  43%|▍| 3/7 [00:01<00:01,  2.92it/s, loss=0.2705, acc=0.88
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.93it/s, loss=0.2705, acc=0.88
# Validation:  57%|▌| 4/7 [00:01<00:01,  2.93it/s, loss=0.2361, acc=0.90
# Validation:  71%|▋| 5/7 [00:01<00:00,  2.93it/s, loss=0.2361, acc=0.90
# Validation:  71%|▋| 5/7 [00:02<00:00,  2.93it/s, loss=0.2618, acc=0.89
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.92it/s, loss=0.2618, acc=0.89
# Validation:  86%|▊| 6/7 [00:02<00:00,  2.92it/s, loss=0.2289, acc=0.90
# Validation: 100%|█| 7/7 [00:02<00:00,  2.91it/s, loss=0.2289, acc=0.90
# Epochs:  19%|▏| 19/100 [23:36<1:40:32, 74.47s/it, trai
# Training:   0%|                                | 0/32 [00:00<?, ?it/s]
# Training:   0%| | 0/32 [00:02<?, ?it/s, loss=0.1786, acc=0.9268, f1=0.
# Training:   3%| | 1/32 [00:02<01:09,  2.25s/it, loss=0.1786, acc=0.926
# Training:   3%| | 1/32 [00:04<01:09,  2.25s/it, loss=0.1893, acc=0.922
# Training:   6%| | 2/32 [00:04<01:07,  2.25s/it, loss=0.1893, acc=0.922
# Training:   6%| | 2/32 [00:06<01:07,  2.25s/it, loss=0.1814, acc=0.929
# Training:   9%| | 3/32 [00:06<01:05,  2.25s/it, loss=0.1814, acc=0.929
# Training:   9%| | 3/32 [00:09<01:05,  2.25s/it, loss=0.1735, acc=0.930
# Training:  12%|▏| 4/32 [00:09<01:03,  2.25s/it, loss=0.1735, acc=0.930
# Training:  12%|▏| 4/32 [00:11<01:03,  2.25s/it, loss=0.1765, acc=0.931
# Training:  16%|▏| 5/32 [00:11<01:00,  2.25s/it, loss=0.1765, acc=0.931
# Training:  16%|▏| 5/32 [00:13<01:00,  2.25s/it, loss=0.1637, acc=0.936
# Training:  19%|▏| 6/32 [00:13<00:58,  2.25s/it, loss=0.1637, acc=0.936
# Training:  19%|▏| 6/32 [00:15<00:58,  2.25s/it, loss=0.1743, acc=0.932
# Training:  22%|▏| 7/32 [00:15<00:56,  2.25s/it, loss=0.1743, acc=0.932
# Training:  22%|▏| 7/32 [00:18<00:56,  2.25s/it, loss=0.1617, acc=0.934
# Training:  25%|▎| 8/32 [00:18<00:54,  2.25s/it, loss=0.1617, acc=0.934
# Training:  25%|▎| 8/32 [00:20<00:54,  2.25s/it, loss=0.1555, acc=0.937
# Training:  28%|▎| 9/32 [00:20<00:51,  2.25s/it, loss=0.1555, acc=0.937
# Training:  28%|▎| 9/32 [00:22<00:51,  2.25s/it, loss=0.1793, acc=0.926
# Training:  31%|▎| 10/32 [00:22<00:49,  2.25s/it, loss=0.1793, acc=0.92
# Training:  31%|▎| 10/32 [00:24<00:49,  2.25s/it, loss=0.1587, acc=0.93
# Training:  34%|▎| 11/32 [00:24<00:47,  2.25s/it, loss=0.1587, acc=0.93
# Training:  34%|▎| 11/32 [00:27<00:47,  2.25s/it, loss=0.1742, acc=0.93
# Training:  38%|▍| 12/32 [00:27<00:45,  2.25s/it, loss=0.1742, acc=0.93
# Training:  38%|▍| 12/32 [00:29<00:45,  2.25s/it, loss=0.1869, acc=0.92
# Training:  41%|▍| 13/32 [00:29<00:42,  2.25s/it, loss=0.1869, acc=0.92
# Training:  41%|▍| 13/32 [00:31<00:42,  2.25s/it, loss=0.1587, acc=0.93
# Training:  44%|▍| 14/32 [00:31<00:40,  2.25s/it, loss=0.1587, acc=0.93
# Training:  44%|▍| 14/32 [00:33<00:40,  2.25s/it, loss=0.1665, acc=0.93
# Training:  47%|▍| 15/32 [00:33<00:38,  2.25s/it, loss=0.1665, acc=0.93
# Training:  47%|▍| 15/32 [00:36<00:38,  2.25s/it, loss=0.2030, acc=0.91
# Training:  50%|▌| 16/32 [00:36<00:36,  2.25s/it, loss=0.2030, acc=0.91
# Training:  50%|▌| 16/32 [00:38<00:36,  2.25s/it, loss=0.1743, acc=0.93
# Training:  53%|▌| 17/32 [00:38<00:33,  2.25s/it, loss=0.1743, acc=0.93
# Training:  53%|▌| 17/32 [00:40<00:33,  2.25s/it, loss=0.1753, acc=0.92
# Training:  56%|▌| 18/32 [00:40<00:31,  2.25s/it, loss=0.1753, acc=0.92
# Training:  56%|▌| 18/32 [00:42<00:31,  2.25s/it, loss=0.1782, acc=0.92
# Training:  59%|▌| 19/32 [00:42<00:29,  2.25s/it, loss=0.1782, acc=0.92
# Training:  59%|▌| 19/32 [00:45<00:29,  2.25s/it, loss=0.1818, acc=0.92
# Training:  62%|▋| 20/32 [00:45<00:27,  2.25s/it, loss=0.1818, acc=0.92
